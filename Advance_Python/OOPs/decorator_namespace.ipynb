# %% [markdown]
# # NameSpace

# %% [markdown]
# - A namespace is a space that holds names(idefiers).Programmatically speaking,namespaces are dictionary of identifiers(keys) and their objects(values).
#     - There are 4 types of namespaces:
#         - Builtin Namespace
#         - Global Namespcae
#         - Enclosing Namespace
#         - Local Namespace
