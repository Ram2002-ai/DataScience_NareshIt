# %%
pip install -U "langchain[openai]"
# Out:
# ...
#    ---------------------------------------- 0.0/548.1 kB ? eta -:--:--
#    ---------------------------------------- 548.1/548.1 kB 2.4 MB/s  0:00:00
# ...
#
#   Attempting uninstall: langchain-core
#
#     Found existing installation: langchain-core 1.3.0
#
#    ------ --------------------------------- 1/6 [langchain-core]
#    ------ --------------------------------- 1/6 [langchain-core]
#     Uninstalling langchain-core-1.3.0:
#    ------ --------------------------------- 1/6 [langchain-core]
#       Successfully uninstalled langchain-core-1.3.0
#    ------ --------------------------------- 1/6 [langchain-core]
#    ------ --------------------------------- 1/6 [langchain-core]
#    ------ --------------------------------- 1/6 [langchain-core]
#    ------ --------------------------------- 1/6 [langchain-core]
#    ------ --------------------------------- 1/6 [langchain-core]
#    ------ --------------------------------- 1/6 [langchain-core]
# ...

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENAI_API_KEY"] = ""

model=init_chat_model("gpt-5.2")
response=model("What is the capital of India?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 os.environ["OPENAI_API_KEY"] = "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"
#       6 model=init_chat_model("gpt-5.2")
# ----> 7 response=model("What is the capital of India?")
#       8 print(response)
#
# TypeError: 'ChatOpenAI' object is not callable
