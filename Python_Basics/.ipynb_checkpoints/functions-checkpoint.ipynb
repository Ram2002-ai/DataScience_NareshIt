# %% [markdown]
# # function
# - function without argument
# -

# %%
def greet():
    print('hello')
    print('good morning')

# %%
greet(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 greet(1)
#
# TypeError: greet() takes 0 positional arguments but 1 was given

# %%
def greet():
    print('hello')
    print('good morning')
greet()

# %%
def greet():
    print('hello')
    print('good morning')
greet()
def greet():
    print('hello')
    print('good morning')
greet()
def greet():
    print('hello')
    print('good morning')
greet()

# %%
# no need to code repeatation
greet()
greet()
greet()

# %%
def add(x,y):
    print(x+y)
add(5)

# %%
def add(x,y):
    print(x+y)
add(5,6)

# %%
add()

# %%
def add(x,y,z): # you have to all arg in input to return result
    print(x+y)
add(5,7)

# %% [markdown]
# # function with return

# %%
def add(x,y):
    return x*y
print(add(45,23))

# %% [markdown]
# # write way to calling function
# - function building in top
# - calling function in bottom

# %%
def greet():
    print('hello')
    print('good morning')
def product(x,y):
    return x*y

greet()
product(3,5)

# %%
def add_sub(x,y):
    c=x-y
    d=x+y
    return c,d
type(add_sub(3,2))

# %%
result,result1=add_sub(4,2)

# %%
result

# %%
result1

# %%
def add_sub_prod(x,y):
    c=x-y
    d=x+y
    e=x*y
    return c,d,e
r1,r2,r3=add_sub_prod(5,6)

# %%
r1

# %%
r2

# %%
r3

# %% [markdown]
# # Function:
# - inbuld function
# - user-defined function -
# - 1. function without argument
#     2. functoin with argument
#        - Formal argument
#        - actual argument
#        - keyword argument
#        - defualt arg
#        - variable length argument
#        - kwargs

# %% [markdown]
# # formal argument:
# - defined at the time of function creation
# # actaul argument:
# - defined at the time of function calling
# - its should be same number of argument as formal argument else its give the error

# %%
def add(a,b): #a,b -- formal argument
    c=a+b
    return c
add(5,6)    #5,6 ---actual argument

# %% [markdown]
# # positional argument
# - its gives at the time of function calling

# %%
def person(name,age):
    print(name)
    print(age)
person('ssioa',22)

# %%
def person(name,age):
    print(name)
    print(age)
person('nit')

# %%
def person(name,age):
    print(name)
    print(age)
person(22)

# %%
def person(name,age):
    print(name)
    print(age)
print('nit',22) #this function ask for the 2 possitional argument

# %%
def person(name,age):
    print(name)
    print(age)
person(22,'nit') #its takes position argument no matters its belogs to formal argument or not

# %%
def person(name,age):
    print(name)
    print(age+1)
person(22,'nit') #  age is str which does not concat with string

# %% [markdown]
# # Keyword Argument
# - keyword argument refers position argument to same format argument
# - its neccesary to all argument should enter with keyword  else its give error

# %%
def person(name,age):
    print(name)
    print(age+1)
person(age=22,name='nit')

# %%
def person(name,age):
    print(name)
    print(age+1)
person(age=22,name='nit') # this time age is concat

# %%
def person(name,age):
    print(name)
    print(age)
person(name='ramde',39) # give the error

# %% [markdown]
# # Default Argument

# %%
def person(name,age):
    print(name)
    print(age)
person('nit')

# %%
def person(name,age=18):
    print(name)
    print(age)
person('nit')

# %%
def person(name,age=18):
    print(age)
    print(name)
person('suhil',23)

# %% [markdown]
# # variable length argument
# - it can accept mutiple argument

# %%
# variable length argument
def sum(a,b):
    c=a+b
    return c
sum(5,6)

# %%
def sum(a,b):
    c=a+b
    return c
sum(5,6,7,8)

# %%
def sum(a,*b):
    c=a+b
    return c
sum(4,5,2,5) # int not concat with tuple

# %%
def sum(a,*b):
    # c=a+b
    print(a)
    print(type(a))

    print(b)
    print(type(b))
sum(5,3,56,4)

# %%
## 1st argument is fixed & we fetch each value from the tuple & we can add them. 

def sum(a,*b):
    c=a
    for i in b:
        c=c+i
    print(c)
sum(5,2,6,7)

# %%
def sum(*a,*b): # we can not assign two keyword argument
    c=a
    for i in b:
        c=c+i
    print(c)
sum(4,5,2,4,3,2,4,-2,24)

# %%
def sum(*a,c):
    print(a)
    print(c)
    for i in a:
        print(i+c)
sum(2,3,4,55,2,4) # in variable length argument we have to assign keyword argument if the variable length arg assign at first

# %%
def sum(*a,c):
    print(a)
    print(c)
    for i in a:
        print(i+c)
sum(2,3,4,55,2,4,c=50)

# %% [markdown]
# # **kwargs
# - its takes n numbers of keyword argument without defined in formal argument
# - its defined at the time of function calling
# - we need to takes a variable for each argument
# - its return the dictionary values

# %%
def sum(**kwargs):
    print(kwargs)
sum(a=(23,22),b=3,c=4)

# %%
def sum(**kwargs):
    print(kwargs)
sum(1,3,3)

# %%
def sum(**kwargs):
    print(kwargs)
sum(a=1,3,b=3) #we have to give keyword for each agrumnet

# %% [markdown]
# # Global & Local
# - local - the variable u deifine inside the function
# - global - the variable u define  outside the function
#
# 1. if use define the local variable then system by default take global as local var
# 2.

# %%
b=1
def a():
    a=17
    return a

print(a())
print(b)

# %% [markdown]
# ### Recursion - a func called itself called recurssion

# %%
def wish():
    print('hello')
    wish()
wish()

# %%
import sys
sys.getrecursionlimit()

# %%
sys.setrecursionlimit(200)
sys.getrecursionlimit()

# %%
sys.setrecursionlimit(3)
sys.getrecursionlimit()

# %%
sys.setrecursionlimit(24)
sys.getrecursionlimit()

# %%
sys.getrecursionlimit()

# %%
import sys
sys.setrecursionlimit(150)
print(sys.getrecursionlimit())

i=0
def wish():
    global i
    i+=1
    print('hello',i)
    wish()
wish()
# Out:
# 150
# hello 1
# hello 2
# hello 3
# hello 4
# hello 5
# hello 6
# hello 7
# hello 8
# hello 9
# hello 10
# hello 11
# hello 12
# hello 13
# hello 14
# hello 15
# hello 16
# hello 17
# hello 18
# hello 19
# hello 20
# hello 21
# hello 22
# hello 23
# hello 24
# hello 25
# hello 26
# hello 27
# hello 28
# hello 29
# hello 30
# hello 31
# hello 32
# hello 33
# hello 34
# hello 35
# hello 36
# hello 37
# hello 38
# hello 39
# hello 40
# hello 41
# hello 42
# hello 43
# hello 44
# hello 45
# hello 46
# hello 47
# hello 48
# hello 49
# hello 50
# hello 51
# hello 52
# hello 53
# hello 54
# hello 55
# hello 56
# hello 57
# hello 58
# hello 59
# hello 60
# hello 61
# hello 62
# hello 63
# hello 64
# hello 65
# hello 66
# hello 67
# hello 68
# hello 69
# hello 70
# hello 71
# hello 72
# hello 73
# hello 74
# hello 75
# hello 76
# hello 77
# hello 78
# hello 79
# hello 80
# hello 81
# hello 82
# hello 83
# hello 84
# hello 85
# hello 86
# hello 87
# hello 88
# hello 89
# hello 90
# hello 91
# hello 92
# hello 93
# hello 94
# hello 95
# hello 96
# hello 97
# hello 98
# hello 99
# hello 100
# hello 101
# hello 102
# hello 103
# hello 104
# hello 105
# hello 106
# hello 107
# hello 108
# hello 109
# hello 110
# hello 111
# hello 112
# hello 113
# hello 114
# hello 115
# hello 116
# hello 117
# hello 118
# hello 119
# hello 120
# hello 121
# hello 122
# hello 123
# hello
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[4], line 11
#       9     print('hello',i)
#      10     wish()
# ---> 11 wish()
#
# Cell In[4], line 10, in wish()
#       8 i+=1
#       9 print('hello',i)
# ---> 10 wish()
#
# Cell In[4], line 10, in wish()
#       8 i+=1
#       9 print('hello',i)
# ---> 10 wish()
#
#     [... skipping similar frames: wish at line 10 (120 times)]
#
# Cell In[4], line 10, in wish()
#       8 i+=1
#       9 print('hello',i)
# ---> 10 wish()
#
# Cell In[4], line 9, in wish()
#       7 global i
#       8 i+=1
# ----> 9 print('hello',i)
#      10 wish()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3056, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3054 if not data:
#    3055     return result
# -> 3056 execution_count = self.execution_count
#    3057 output_stream = None
#    3058 outputs_by_counter = self.history_manager.outputs
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:687, in TraitType.__get__(self, obj, cls)
#     685     return self
#     686 else:
# --> 687     return t.cast(G, self.get(obj, cls))
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:666, in TraitType.get(self, obj, cls)
#     664     raise TraitError("Unexpected error in TraitType: default value not set properly") from e
#     665 else:
# --> 666     return t.cast(G, value)
#
# RecursionError: maximum recursion depth exceeded

# %%
def fact(n):
    if n==0:
        return 1
    return n*fact(n-1)
result=fact(5)
result
# Out:
# 120

# %% [markdown]
# # Lambda Function/Anonymous function
# - function without name called lambda
# - filter()|map()|reduce()

# %% [markdown]
# # Python Decorators
# - assign with @ symbols
#   used in-
#           class method
#           static method
#           abstract method
#
# # module creation
#     inbuild module -- numpy 255f function ,pandas function,seaborn
#     user define module-user build own
