# %% [markdown]
# # python object oriented programing language.
# # Python name comes from "complete montis python flying circus".
# # Python Dynamic Programing Language.
# # Python is plateform independent. Same code works on different operating system.
# # Python is open source.
# # pros and cons
# # python can not used in mobile application
# # Python IDE(intrigated development enviroment)-user write the code,run the code,debug the code.
# # interpreter vs compiler
# # interpreter - run or excute the code line by line
# # compiler- run the code whole at once
# import sys
# sys.version
# a=True
# type(a)

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # Python varible
# 1. does not start with digit but end with number
# 2. case sensitive
# 3. special character not allowed
# 4. only _ is allowed
#
# variable

# %%
_v=20
_v
# Out:
# 20

# %%
v_@=65
v_@
# Out:
#   Cell In[10], line 2
#     v_@
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# len(keyword.kwlist)

# %%
s='surnamewala'

# %%
s
# Out:
# 'surnamewala'

# %%
s[-1]
# Out:
# 'a'

# %%
s[:-2]
# Out:
# 'surnamewa'

# %%
s[-2:]
# Out:
# 'la'

# %%
s[-6:]
# Out:
# 'mewala'

# %%
print(python -- version)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(python -- version)
#
# NameError: name 'python' is not defined

# %%
import python
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import python
#
# ModuleNotFoundError: No module named 'python'

# %%
pip --version
# Out:
# pip 25.1 from C:\Users\USER\anaconda3\Lib\site-packages\pip (python 3.13)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
def greet(name):
    greet =f'Hello! {name} , Have a great Day.'
    question= greet+"\nHow May I help you?"
    answer=question+'\nOhhh Yes How many Student do you have in the school'
    return answer,greet,question
print(greet('Sahil Yadav'))
# Out:
# ('Hello! Sahil Yadav , Have a great Day.\nHow May I help you?\nOhhh Yes How many Student do you have in the school', 'Hello! Sahil Yadav , Have a great Day.', 'Hello! Sahil Yadav , Have a great Day.\nHow May I help you?')

# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
print(keyword.kwlist) # list of all keyword in python (35)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist) #python has 35 keywords
# Out:
# 35

# %% [markdown]
# **Identifiers:**
# An identifier is a name given to entities like class, functions,varaible,etc.It helps to diffentiate one entity from another

# %%
1var=10 # indentifier can't start with numbers
# Out:
#   Cell In[5], line 1
#     1var=10
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@=35 # identifier can't use special symbols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 val2@=35
#
# NameError: name 'val2' is not defined

# %%
import=125 #identifier can't use keyword
# Out:
#   Cell In[7], line 1
#     import=125
#           ^
# SyntaxError: invalid syntax

# %%
Val=10 # only underscore is allowed
var_1=10 #indentifier can be a combination of letters in lowercase (a to z) or uppercase

# %% [markdown]
# **Comment In Python:**
# Comments can be used to explain the code for more readability.

# %%
# single line comment
val=10

# %%
'''multiple 
line 
comment'''
val_1=1

# %% [markdown]
# **Statement:**
# Instrcuction that a python interpreter can execute

# %%
p=20 # p point a memory location for storin 20
q=20 # pointing the same memory location for q var
r=q
print(p,type(p),hex(id(p)))
print(q,type(q),hex(id(q)))
print(r,type(r),hex(id(r)))
# Out:
# 20 <class 'int'> 0x7ff83d02b608
# 20 <class 'int'> 0x7ff83d02b608
# 20 <class 'int'> 0x7ff83d02b608

# %% [markdown]
# **Variable Assignment**

# %%
intvar=10 #integer variable
floatvar=1.2 # float variable
strvar='Python Language' # string variable
boolvar=True or False #Boolean variable
print(intvar)
print(floatvar)
print(strvar)
print(boolvar)
# Out:
# 10
# 1.2
# Python Language
# True

# %% [markdown]
# **Multiple Assignments**

# %%
inrvar,flaotvar,strvar,boolvar=10,20.3,'Python Language',False
#using commas to seperate
print(intvar)
print()

# %%
p1=p2=p3=p4=44 # all variables pointing to same value
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %% [markdown]
# # Python Operator
# ** 1. Arithmatic operator 2. Assigment operator 3.

# %% [markdown]
# # Arithmatic Operator

# %%
x=10
y=3
x+y
# Out:
# 13

# %%
x-y
# Out:
# 7

# %%
x*y
# Out:
# 30

# %% [markdown]
# # Assignment Operator

# %% [markdown]
# # print result with string

# %%
num1=20
num2=30
add=num1+num2

# %%
print(f"addition of {num1} and{num2} is {add}")
# Out:
# addition of 20 and30 is 50

# %%
# print with formating
print("The addition of {} and {} is {}.".format(num1,num2,add))
# Out:
# The addition of 20 and 30 is 50.

# %%
num3=50

# %%
add +=num3

# %%
print("The addition of {} and {} and {} is {}.".format(num1,num2,num3,add))
# Out:
# The addition of 20 and 30 and 50 is 100.

# %%
# print with f string method

# %%
print(f"addition of {num1} and{num2} and is {add}")
