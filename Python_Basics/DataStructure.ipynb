# %% [markdown]
# # Data Type vs Datastructure
# 1.user always define only 1 value/datastructure user will defined more than 1 value
#
# 2.data stucture is collection of data types
#
# 3.metrix is collection of datastructure(array)
#
# 4.table - collection of rows & columns
#
# Scalar:number[3]
#
# Vector:collection of scaler
#
# array: collection of vector
#
# Tensor:collection of array
#
# -- DATA STRUCTURE--
#
# Inbuild data structure: Primitive
# LIST
# TUPLE
# SET
# DICTIONARY
# RANGE
#
# User define data structure:
# Non Primitive
# STACK
# TREE
# QUEUE
# ARRAY
# User define data str will take care by library like- numpy , pandas

# %% [markdown]
# # Data Structure:List
# <!-- list define [] -->
# <!-- append(): add value or element atlast -->
# <!-- list is growable -->
# <!-- multiple datatype is allowed in list -->
# <!-- copy(): copy one list to another list -->
# <!-- list is mutable(changeable) -->
# <!-- duplicate is allowed -->
# <!-- remove the element from list -->

# %%
l=[]

# %%
type(1)
# Out:
# int

# %%
len(l)
# Out:
# 0

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)

# %%
l.append(30)
l.append(40)

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
len(l)
# Out:
# 4

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l=l1

# %%
l==l1
# Out:
# True

# %%
l1.append('nit')
l1.append(True)
l1.append(1+2j)
l1.append(9.7)

# %%
l1
# Out:
# [10, 20, 30, 40, 'nit', True, (1+2j), 9.7]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 'nit', True, (1+2j), 9.7]
# [10, 20, 30, 40, 'nit', True, (1+2j), 9.7]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
l
# Out:
# []

# %%
l.append(20)
l
# Out:
# [20]

# %%
l1
# Out:
# [20]

# %%
l2=[20,30,40,50,True,'nit',3.2]
l2
# Out:
# [20, 30, 40, 50, True, 'nit', 3.2]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [20]
# [20]
# [20, 30, 40, 50, True, 'nit', 3.2]

# %%
l2[:]
# Out:
# [20, 30, 40, 50, True, 'nit', 3.2]

# %%
l1[:]
# Out:
# [20]

# %%
l2[0]=10000

# %%
l2
# Out:
# [10000, 30, 40, 50, True, 'nit', 3.2]

# %%
l.append(30)
l.append(50)

# %%
l
# Out:
# [20, 30, 50]

# %%
l[-1]=100

# %%
l
# Out:
# [20, 30, 100]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [20, 30, 100]
# [20, 30, 100]
# [10000, 30, 40, 50, True, 'nit', 3.2]

# %%
l1.clear()

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# []
# [10000, 30, 40, 50, True, 'nit', 3.2]

# %%
del l1

# %%
print(l1,l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 print(l1,l)
#
# NameError: name 'l1' is not defined

# %%
l2.count(30)
# Out:
# 1

# %%
l2.append(30)

# %%
l2.count(30)
# Out:
# 2

# %%
l2[::-1]
# Out:
# [30, 3.2, 'nit', True, 50, 40, 30, 10000]

# %%
l2[::2]
# Out:
# [10000, 40, True, 3.2]

# %%
l2[::-2]
# Out:
# [30, 'nit', 50, 30]

# %%
l3=[]
l4=[]
del l3,l4

# %% [markdown]
# # 30 dec

# %%
l=[]
l.append(20)
l.append('nit')
l.append(1+3)
l.append(True)

# %%
l
# Out:
# [20, 'nit', 4, True]

# %%
l1=[21,23,34,2,21,"hello",(2+3j)]

# %%
l3=l1.copy()

# %%
l3
# Out:
# [21, 23, 34, 2, 21, 'hello', (2+3j)]

# %%
l3.remove((2+3j))

# %%
l3
# Out:
# [21, 23, 34, 2, 21, 'hello']

# %%
l1
# Out:
# [21, 23, 34, 2, 21, 'hello', (2+3j)]

# %%
l2=[]

# %%
print(l)
print(l1)
print(l3)
print(l2)
# Out:
# [20, 'nit', 4, True]
# [21, 23, 34, 2, 21, 'hello', (2+3j)]
# [21, 23, 34, 2, 21, 'hello']
# []

# %%
l2.extend(l)

# %%
l2
# Out:
# [20, 'nit', 4, True]

# %%
l2.extend(l1)

# %%
l2
# Out:
# [20, 'nit', 4, True, 21, 23, 34, 2, 21, 'hello', (2+3j)]

# %%
l2.remove(20)

# %%
l2
# Out:
# ['nit', 4, True, 21, 23, 34, 2, 21, 'hello', (2+3j)]

# %%
l1
# Out:
# [21, 23, 34, 2, 21, 'hello', (2+3j)]

# %%
l
# Out:
# [20, 'nit', 4, True]

# %%
l1.index(21) # in duplicate the first element index show
# Out:
# 0

# %%
l1.index(34)
# Out:
# 2

# %%
l1.insert(1,15) # insert the element before the index 1, which become 1 index

# %%
l1
# Out:
# [21, 15, 23, 34, 2, 21, 'hello', (2+3j)]

# %%
l2
# Out:
# ['nit', 4, True, 21, 23, 34, 2, 21, 'hello', (2+3j)]

# %% [markdown]
# # pop will remove last element from the list without any argument, if it has argument(index) it will remove the specific element
# #remove eliminate the value from the list not index where pop is remove the index

# %%
l2.pop()
# Out:
# (2+3j)

# %% [markdown]
# # reverse

# %%
print(l)
print(l1)
print(l2)
print(l3)
# Out:
# [20, 'nit', 4, True]
# [21, 15, 23, 34, 2, 21, 'hello', (2+3j)]
# ['nit', 4, True, 21, 23, 34, 2, 21, 'hello']
# [21, 23, 34, 2, 21, 'hello']

# %%
l.reverse()

# %%
l
# Out:
# [True, 4, 'nit', 20]

# %%
l1.reverse()

# %%
l1
# Out:
# [(2+3j), 'hello', 21, 2, 34, 23, 15, 21]

# %%
l2.reverse()

# %%
l2
# Out:
# ['hello', 21, 2, 34, 23, 21, True, 4, 'nit']

# %% [markdown]
# # Sort

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
l4=[20,1,67,2,21,100,45]

# %%
l4.sort() # parameter tunning

# %%
l4
# Out:
# [1, 2, 20, 21, 45, 67, 100]

# %%
l5=['z','a','r','d']

# %%
l5.sort()

# %%
l5
# Out:
# ['a', 'd', 'r', 'z']

# %%
l5.sort(reverse=True) # hyperperameter tunning

# %%
l5
# Out:
# ['z', 'r', 'd', 'a']

# %% [markdown]
# #parameter tunning--inbuild os
# hyperparameter tunning --user or developer change inbuild os /basicaly changing the paratemers

# %%
l=[10,20,20,30,40,'nit',2.5,True]

# %%
l.index('nit')
# Out:
# 5

# %%
l[5][0] #Nested Index
# Out:
# 'n'

# %%
l[2:10:5] #step indexing
# Out:
# [20, True]

# %%
l[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 l[10]
#
# IndexError: list index out of range

# %%
l[:10]
# Out:
# [10, 20, 20, 30, 40, 'nit', 2.5, True]

# %%
l[10:] #list t
# Out:
# []

# %% [markdown]
# # list is completed

# %% [markdown]
# # Tuple

# %%
t=()

# %%
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=(10,20,30,40)
t1
# Out:
# (10, 20, 30, 40)

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index(30)
# Out:
# 2

# %%
t1[:] # slicing is possible
# Out:
# (10, 20, 30, 40)

# %%
t1.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 t1.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
icici=(12345,'ciafd3223',456)
icici
# Out:
# (12345, 'ciafd3223', 456)

# %%
icici.remove(12345)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 icici.remove(12345)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# # tuple is immutable

# %%
t1[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 t1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
10 in l #list memberships
# Out:
# True

# %%
100 in l
# Out:
# False
