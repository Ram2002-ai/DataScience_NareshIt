# %% [markdown]
# **DATA TYPES:**
# **NUMERIC**

# %%
import sys
val1=7 #integer data type
print(val1)
print(type(val1))
print(sys.getsizeof(val1))
print(val1,'is integer',isinstance(val1,int))
# Out:
# 7
# <class 'int'>
# 28
# 7 is integer True

# %%
val2=91.3 #float data type
print(val2)
print(type(val2))
print(sys.getsizeof(val2))
print(val2,'is Float?',isinstance(val2,float))
# Out:
# 91.3
# <class 'float'>
# 24
# 91.3 is Float? True

# %%
2e0 # only e letter is allowed in float
3E12
# Out:
# 3000000000000.0

# %%
val3=25+10j # complex data type , Only j/J letter allowed 
print(val3)
print(type(val3))
print(sys.getsizeof(val3))
print(val3,'is Float?',isinstance(val3,complex))
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j) is Float? True

# %%
2e2
# Out:
# 200.0

# %%
val3.real
# Out:
# 25.0

# %%
val3.imag
# Out:
# 10.0

# %%
sys.getsizeof(int())
# Out:
# 28

# %%
sys.getsizeof(float())
# Out:
# 24

# %%
sys.getsizeof(complex())
# Out:
# 32

# %% [markdown]
# **Boolean:** Boolean data type can have only two possible values True or False.
# the numeriac value for True=1 and for False=0

# %%
bool1=True
print(bool1)
print(type(bool1))
print(isinstance(bool1,bool)) #checking is boolean or not
# Out:
# True
# <class 'bool'>
# True

# %%
bool=true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 bool=true
#
# NameError: name 'true' is not defined

# %%
print(True+True)
print(True-False)
print(True-False*False)
print(False/True)
print(True/False)
# Out:
# 2
# 1
# 1
# 0.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[85], line 5
#       3 print(True-False*False)
#       4 print(False/True)
# ----> 5 print(True/False)
#
# ZeroDivisionError: division by zero

# %%
bool2=False
print(type(bool2))
print(isinstance(bool2,bool))
# Out:
# <class 'bool'>
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(False)
# Out:
# False

# %% [markdown]
# **STRING:**
# **STRING CREATION**

# %%
str1='hello python' # define string using single quotes
print(str1)
print(type(str1))
# Out:
# hello python
# <class 'str'>

# %%
mystr="hello world" #define string using double quotes
mystr
# Out:
# 'hello world'

# %%
mystr='''hello
world''' #define string using triple quotes
mystr
# Out:
# 'hello\nworld'

# %%
mystr2='Woohoo '
mystr2=mystr2*5
print(mystr2)
print(len(mystr2))
# Out:
# Woohoo Woohoo Woohoo Woohoo Woohoo
# 35

# %% [markdown]
# **String Indexing:**
# Two types of string Indexing 1. Forward Indeing 2. Backward Indexing

# %%
str1
# Out:
# 'hello python'

# %%
# forward indexing
str1[0] # First character of string
# Out:
# 'h'

# %%
# Backward Indexing
str1[len(str1)-1]# last character in string using len function
# Out:
# 'n'

# %%
str1[-1]
# Out:
# 'n'

# %%
myworld="My world is the greatest palce in the universe .Here are to many living things"

# %%
myworld[10]
# Out:
# 's'

# %% [markdown]
# **String Slicing**

# %%
myworld[0:16] #String Slicin _Fetch All character from 0 to 15 index location it fetches the inddex till n-1
# Out:
# 'My world is the '

# %%
myworld[0:-3]
# Out:
# 'My world is the greatest palce in the universe .Here are to many living thi'

# %%
myworld[:]
# Out:
# 'My world is the greatest palce in the universe .Here are to many living things'

# %%
myworld[:18] #all character before 18 index
# Out:
# 'My world is the gr'

# %%
myworld[::-1] # backword sling , Reverse the string
# Out:
# 'sgniht gnivil ynam ot era ereH. esrevinu eht ni eclap tsetaerg eht si dlrow yM'

# %%
myworld[0:30:2] #steps slicing
# Out:
# 'M ol stegets ac'

# %%
str1
# Out:
# 'hello python'

# %%
# string are immutable which means elements of string can't chage once it declare means it  remains samema
str1[0:5]='holaa'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 str1[0:5]='holaa'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1 # del the str1

# %%
str1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 str1
#
# NameError: name 'str1' is not defined

# %% [markdown]
# **Data Concatenation**

# %%
s='Hello!'
s1=' I am'
s2=''
s3=' sorry'
s2=s3
s4=s+s1+s2
s4
# Out:
# 'Hello! I am sorry'

# %% [markdown]
# **Type Casting:**
# All other data type to Integer

# %%
int(2.3) # float to int
# Out:
# 2

# %%
int(True)#bool to int
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(10+8j) #complex to int not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 int(10+8j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')#string to integer
# Out:
# 10

# %%
int('ten') # character string to int not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(2.3,4.5) # two argument not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 int(2.3,4.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# **All other to Float**

# %%
float(11)# int to float
# Out:
# 11.0

# %%
float(True)#bool to float
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)# not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# # other datatype to complex

# %%
complex(10) # int to complex
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10+20)
# Out:
# (30+0j)

# %%
complex(9.7)
# Out:
# (9.7+0j)

# %%
complex(9.7,3.2)
# Out:
# (9.7+3.2j)

# %%
complex(False,True)#bool to complex
# Out:
# 1j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# # All other to string

# %%
str(1) # int to str
# Out:
# '1'

# %%
str(2.4) #float to str
# Out:
# '2.4'

# %%
str(False)#Boolean to string
# Out:
# 'False'

# %%
str(1+3j) # complex to str
# Out:
# '(1+3j)'

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %% [markdown]
# # Revision of Python Data types

# %% [markdown]
# # local system:- install the software in pc
# # distributed system:- multiple system connect at once. ex-hadoop

# %%
i=34
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 i=34
# ----> 2 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
i1=9
i1
# Out:
# 9

# %%
type(i1)
# Out:
# int

# %% [markdown]
# # function: 1.inbuild function 2.User define function
# # function always ends with the ()

# %%
f,f1=9.3,8.3
type(f)
# Out:
# float

# %% [markdown]
# # in float only (e or E ) letter is allowed

# %%
f2=2e1
f2
# Out:
# 20.0

# %%
f3=2e-1
f3
# Out:
# 0.2

# %%
f4=3.2e3
f4
# Out:
# 3200.0

# %%
f5=30.2E-1
f5
# Out:
# 3.02

# %%
f6=3a1 #other letter not accept by float
# Out:
#   Cell In[23], line 1
#     f6=3a1
#        ^
# SyntaxError: invalid decimal literal

# %%
id(f,f1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 id(f,f1)
#
# TypeError: id() takes exactly one argument (2 given)

# %% [markdown]
# # id() : give information about the address of memory location
# # type(): give information about the type of variable . like integer,float,strings etc

# %%
id(f)
# Out:
# 2176153206480

# %%
id(f2)
# Out:
# 2176188130320

# %% [markdown]
# # print(): if i want to see all the output then print() are use
# # print(): function will print statement or print the output

# %% [markdown]
# # e0=1.0,e1=10.0,E2=100.0----------

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# # boolean datatype always starts with capitale letter

# %%
True+True
# Out:
# 2

# %%
# python identify the datatypes automaticaly.(thats why python is dynamic typed language)

# %%
sys.getsizeof(str())
# Out:
# 41

# %%
sys.getsizeof(list())
# Out:
# 56

# %%
sys.getsizeof(tuple())
# Out:
# 40

# %%
sys.getsizeof(set())
# Out:
# 216

# %%
sys.getsizeof(dict())
# Out:
# 64

# %%
sys.getsizeof(None)
# Out:
# 16

# %%
print(sys.getsizeof(int))
# Out:
# 416

# %% [markdown]
# # complex

# %% [markdown]
# # complex -every time you need to write (a+bj)
# # it is in only python
# # very good for math calculation
# # only j or J letter allowed
# # 1 real part,+ operator, 2 imaginary part, j square root of -1

# %%
c=1+2j # 1 real part,+ operator, 2 imaginary part, j square root of -1
c
# Out:
# (1+2j)

# %%
a=1+1a
# Out:
#   Cell In[13], line 1
#     a=1+1a
#         ^
# SyntaxError: invalid decimal literal

# %%
b=c.conjugate() #negative

# %%
d=5+6j
print(c)
print(d)
# Out:
# (1+2j)
# (5+6j)

# %%
c+d
# Out:
# (6+8j)

# %%
b+c
# Out:
# (2+0j)

# %% [markdown]
# # string

# %% [markdown]
# # allways starts with '',"",'''''',""""""
# # if user want write line then quotes ''or ""
# # if multi line """""" or ''''''

# %%
a="""hello
how 
are 
you"""
a
# Out:
# 'hello\nhow \nare \nyou'

# %%
b='hello
how'
# Out:
#   Cell In[23], line 1
#     b='hello
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
c='''hello
a
s'''
c
# Out:
# 'hello\na\ns'

# %% [markdown]
# # 3 hours practicle work for give assignment
# # 15 minut of typing
# # 2 hours of memorizing
# # 2 hours for project
# # 1 softskills:communication, writing skill, email
# # 2 hours dedicated in class

# %%
# gemma370m 
# ollama pull gemma3:270m
# ollama run gemma3:270m

# %% [markdown]
# # String Revision (Advance Strig)

# %%
hi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hi
#
# NameError: name 'hi' is not defined

# %%
#hi

# %%
'hi'
# Out:
# 'hi'

# %%
s1='hello'
s1
# Out:
# 'hello'

# %%
3+'nit'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 3+'nit'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
'nit'+'nit'
# Out:
# 'nitnit'

# %%
"nit"*'nit' #string to string can not multiply
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 "nit"*'nit'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
5*' nit' #str *int can be print
# Out:
# ' nit nit nit nit nit'

# %%
print("C:\Users\USER\DataScience_NareshIt") #
# Out:
#   Cell In[16], line 1
#     print("C:\Users\USER\DataScience_NareshIt") #
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# Raw string is very important because we read the path of the file
print(r"C:\Users\USER\DataScience_NareshIt") # r-Raw String
# Out:
# C:\Users\USER\DataScience_NareshIt

# %%
tax=20
price=15
price*tax
# Out:
# 300

# %%
price+_ #(-) it stores previous value
# Out:
# 315

# %%
tax+_
# Out:
# 335

# %%
round(20.4322) # round round the decimal number
# Out:
# 20

# %%
round(30.233,2)
# Out:
# 30.23

# %%
help() #help()-provide help
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  symbols
# Here is a list of the punctuation symbols which Python assigns special meaning
# to. Enter any symbol to get more help.
#
# !=                  +                   <<=                 _
# "                   +=                  <=                  __
# ...

# %%
'doesn\'t' # (\)to skip the (') inside the string
# Out:
# "doesn't"

# %%
"doesn\'t"
# Out:
# "doesn't"

# %%
"doesn't"
# Out:
# "doesn't"

# %%
"Yes,"they said."
# Out:
#   Cell In[4], line 1
#     "Yes,"they said"
#                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
3 *'un'+'ium'
# Out:
# 'unununium'

# %%
index='welcome to hydrabad'
index
# Out:
# 'welcome to hydrabad'

# %%
print(index[0])
print(index[1])
print(index[2])
print(index[3])
print(index[4])
print(index[5])
# Out:
# w
# e
# l
# c
# o
# m

# %%
for i in index:
    print(i)
# Out:
# w
# e
# l
# c
# o
# m
# e
#
# t
# o
#
# h
# y
# d
# r
# a
# b
# a
# d

# %%
index[-100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 index[-100]
#
# IndexError: string index out of range

# %%
index[-1]
# Out:
# 'd'

# %% [markdown]
# # String Slicing
# slice means (all)

# %%
index='welcome'

# %%
len(index) # len() gives count of digit
# Out:
# 7

# %% [markdown]
# # pakage= collection of module
# # module= collection of function
# # function= reuable code
# # two types of function 1. inbuild 2.user defined
# from sklearn.tree import decisiontree
# sklearn=pakage
# tree=module
# function=function

# %%
index[:] #all char of the strings
# Out:
# 'welcome'

# %%
# left index always starts with 0
# right index ends with (n-1)

# %%
index[:5] # from 5 index all char excluded
# Out:
# 'welco'

# %%
index[5:] # from 5 to n-1 all char
# Out:
# 'me'

# %%
index[4:10]
# Out:
# 'ome'

# %%
index[:10]
# Out:
# 'welcome'

# %%
index[10:] #it returns empty list (slicing in indexing never gives error it return if value is exists or give empty string)
# Out:
# ''

# %%
index[10] #index out of range(not found)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 index[10]
#
# IndexError: string index out of range

# %%
s3='hellopython'
s3
# Out:
# 'hellopython'

# %%
index[3:-1] #
# Out:
# 'com'

# %%
index[3:2]
# Out:
# ''

# %%
index[3:2:-1]
# Out:
# 'c'

# %%
s3[0:8]
# Out:
# 'hellopyt'

# %%
i5='nasheshit'
i5[0:5]
# Out:
# 'nashe'

# %%
i5[::-2]
# Out:
# 'thesn'

# %%
i5[::-3]
# Out:
# 'tss'

# %%
i5[::-1]
# Out:
# 'tihsehsan'

# %% [markdown]
# # data--2 part
# 1.structure data--supervisedleraning--labeled data(csv,excel)[machile learning]
# 2.unstructured data--unsupervisedlearning-unlabeled data(image,audio,video,xml,streaming)[ai,genai,agenticai]
# 3.reinforecement learning(track the data and make prediction)
#
# machile learning=- machine will learn historical data

# %% [markdown]
# 1.datatype user defined only one value
# 2.datastructure user defined more than one value
# 3.matrix =array in python (collection of vector)
# 4.collection of array is tensor(pytorch)
# 5.image =collection of tensors
# 6.speech=text data
# 7.video=collection of images
#
# structured data[bank,insurance,heathcare]
# unstructure data[netflix,amazon,weath,ipl live,fashion]

# %%
scaler=[1] just a number
vector=[1 2
        3 4] collection of scaler
