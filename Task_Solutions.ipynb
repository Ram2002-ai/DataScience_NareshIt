# %%
age=25
print(age)
# Out:
# 25

# %%
number=20
print(number-1)
# Out:
# 19

# %%
# Sum of two numbers
a,b=23,20
sum=a+b
print(sum)
# Out:
# 43

# %%
# Area of a Rectangle
lenght=45
width=76
area=lenght*width
print(area)
# Out:
# 3420

# %%
# Area of a circle
radius=8.9
pi=3.14
area=radius**2*pi
print(area)
# Out:
# 248.71940000000004

# %%
# string concatanation
a='Learning'
b=' is fun!'
print(a+b)
# Out:
# Learning is fun!
