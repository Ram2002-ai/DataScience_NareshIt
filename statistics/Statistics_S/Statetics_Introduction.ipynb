# %% [markdown]
# # Statestics
# **STEPS TO STATS**
# 1. POPULATION VS SAMPLE
# 2. TYPES OF DATA
# 3. DESCRIPTIVE STATS
# 4. INFERENTIAL STATS
# 5. ADDVANCE STATS
# 6. LINEAR GRAPH STATS TO ML PLOTS
#
#
# # SAMPLING TECHNIQUE
# - Population to sample
#
# # INFERENCE TECHNIQUE
# -  sample to Population
#
# **Population Characterstics--parameter|sample charaterstics-statistics**
#
# - 99% work in ml on sample data

# %% [markdown]
# # Types Of Data
# 1. Categorical:
#        - yes | No (dependent variable is binary)
# 2. Numerical
#       -  Discrete  (No depenent variable) (data will stop some certain points--marks,ratting),clustering
#       -  Continous (dependent variable ) (regression model)--ML

# %% [markdown]
# # Levels of Measurement
# 1. Qualitative
#      - Nominal(Random Data) like - summer winter rain winter
#      - Ordinal(Ordered Data) like- (1* rate food,2,3,4,5)
# 2. Quantative
#      - Interval (Range Data)
#      - Ratio  ()

# %% [markdown]
# # Descriptive Stats
# - measure of central tendency
#   **Mean | Median | Mode**
# - measure of assymetry
#   **Skewness | Kurtosis**
# - measure of variability
#   **Variance | Standard Deviation | coefficient of variation**
#
# **Population Mean (muuuu)**
# **sample mean -- x bar**
#
#
#
#
#
#
#
#
#
#
#
# **Measures of Asymetry**- it show the graph data is located data is left side or data is right side or data is center
# # Skewnes
#  - Positive Skew ->(mean>median and mode) (data is in left & outlier is at right)
#  - Negetive Skew ->(Mode > median and mean) (data is in right & outlier is at left)
#  - 0 Skew -> (mean=median=mode) (data stay at center)
#
#
#
# - 0 Skew == normal distribution == bell curve == guasian distribution == symmetric distribution

# %% [markdown]
# # Scipy
# - scientific library

# %%
# Kurtosis
