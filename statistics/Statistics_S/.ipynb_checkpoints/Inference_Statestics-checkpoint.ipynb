# %% [markdown]
# # Inference Statestics
# - when roll 1 dice -- uniform distribution(not reccomnded)
# - when roll2 dice --- normal distribution
#
# ##### Distribution concept  born from probability | prob & distrib part of the inferential stats
# - probabilty
# - distribution
# - z-test
# - t-test
# - z-table,t-table
# - confidence level
# - hypothesis testing
# - accept the null hypothesis
# - p-value
# - reject the null hypothesis
#
# ### advance stats
# - ssr
# - sst
# - mae
# - mse
# - rmse
# - r2
# - adjust r2
# - loss|cost|residual|ols

# %% [markdown]
# ##  Confidence Interval
# - 1. population== population variance known if we test this test is called z-test
#   2. sample== sample variance unknown== if we test this test is call t-test
