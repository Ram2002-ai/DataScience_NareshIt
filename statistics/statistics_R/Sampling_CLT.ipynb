# %% [markdown]
# ### We will simulate a "Population" of 1 million customers with an average spend of $500. Then, we will see how sampling works in the real world.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. create Population Data (1 million customers)
np.random.seed(42)
population_spend=np.random.exponential(scale=500,size=1000000)
pop_mean=np.mean(population_spend)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:34
#      30 del _hard_dependencies, _dependency
#      32 try:
#      33     # numpy compat
# ---> 34     from pandas.compat import (
#      35         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      36     )
#      37 except ImportError as _err:  # pragma: no cover
#      38     _module = _err.name
#
# File ~\anaconda3\Lib\site-packages\pandas\compat\__init__.py:28
#      18 from pandas.compat._constants import (
#      19     CHAINED_WARNING_DISABLED,
#      20     IS64,
#    (...)
#      25     WASM,
#      26 )
#      27 from pandas.compat.numpy import is_numpy_dev
# ...
