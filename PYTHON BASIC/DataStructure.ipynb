# %% [markdown]
# IN python  programing datastuctures are
# Data Type vs Datastructure
# 1.user always define only 1 value/datastructure user will defined more than 1 value
# 2.data stucture is collection of data types
# 3.metrix is collection of datastructure(array)
# 4.table - collection of rows & columns
#
# Scalar:number[3]
#
# Vector:collection of scaler
#
# array: collection of vector
#
# Tensor:collection of array
#
# -- DATA STRUCTURE--
#
# Inbuild data structure: Primitive
# LIST
# TUPLE
# SET
# DICTIONARY
# RANGE
#
# User define data structure:Non Primitive
# STACK
# TREE
# QUEUE
# ARRAY
# User define data str will take care by library like- numpy , pandas

# %% [markdown]
# # Data Structure:List
# list define []
# append(): add value or element atlast
# list is growable
# multiple datatype is allowed in list
# copy(): copy one list to another list
# list is mutable(changeable)

# %%
l=[]

# %%
type(1)
# Out:
# int

# %%
len(l)
# Out:
# 0

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)

# %%
l.append(30)
l.append(40)

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
len(l)
# Out:
# 4

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l=l1

# %%
l==l1
# Out:
# True

# %%
l1.append('nit')
l1.append(True)
l1.append(1+2j)
l1.append(9.7)

# %%
l1
# Out:
# [10, 20, 30, 40, 3, 'nit', True, (1+2j), 9.7]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 3, 'nit', True, (1+2j), 9.7]
# [10, 20, 30, 40, 3, 'nit', True, (1+2j), 9.7]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
l
# Out:
# []

# %%
l.append(20)
l
# Out:
# [20]

# %%
l1
# Out:
# [20]

# %%
l2=[20,30,40,50,True,'nit',3.2]
l2
# Out:
# [20, 30, 40, 50, True, 'nit', 3.2]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [20]
# [20]
# [20, 30, 40, 50, True, 'nit', 3.2]

# %%
l2[:]
# Out:
# [20, 30, 40, 50, True, 'nit', 3.2]

# %%
l1[:]
# Out:
# [20]

# %%
l2[0]=10000

# %%
l2
# Out:
# [10000, 30, 40, 50, True, 'nit', 3.2]

# %%
l.append(30)
l.append(50)

# %%
l
# Out:
# [20, 30, 50]

# %%
l[-1]=100

# %%
l
# Out:
# [20, 30, 100]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [20, 30, 100]
# [20, 30, 100]
# [10000, 30, 40, 50, True, 'nit', 3.2]

# %%
l1.clear()

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# []
# [10000, 30, 40, 50, True, 'nit', 3.2]

# %%
del l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 del l1,l
#
# NameError: name 'l1' is not defined

# %%
print(l1,l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print(l1,l)
#
# NameError: name 'l1' is not defined

# %%
l2.count(30)
# Out:
# 1

# %%
l2.append(30)

# %%
l2.count(30)
# Out:
# 2

# %%
l2[::-1]
# Out:
# [30, 3.2, 'nit', True, 50, 40, 30, 10000]

# %%
l2[::2]
# Out:
# [10000, 40, True, 3.2]

# %%
l2[::-2]
# Out:
# [30, 'nit', 50, 30]

# %%
l3=[]
l4=[]
del l3,l4
