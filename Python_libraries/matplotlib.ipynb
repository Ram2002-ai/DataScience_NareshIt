# %%
import matplotlib.pyplot as plt

# %%
plt.gca()
# Out:
# <Axes: >

# %%
plt.gcf()

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
plt.plot([1,2,3,4],[1,2,9,16],'bo')
plt.axis([0,6,0,20])
plt.show()
