# %% [markdown]
# # EDA(Exploratory Data Analysis)
# - EDA is parent for machine learning.
# - EDA is foundation  for machine learning.
# - without EDA no data scientist build predictive model.
# -  in EDA collect raw data and perform some operation to clean the data
# ![image.png](attachment:d88468f6-ed5c-4ce8-bf1d-01a3c6c23deb.png)!

# %% [markdown]
# # Machine learning
# - Machine learning has 3 categories
# - 1. Regression model (dependent variable is continous)
#
#   2. Classification Model (dependent variable is categorical)
#
#   3. Clustering Model (no dependent variable)

# %% [markdown]
# # types of companies
# - service based company
# - product based  company

# %% [markdown]
# # EDA Techniques
# 1. variable identification
# 2. univariate analysis
# 3. bivariate analysis
# 4. outlier treatment
# 5. missing value treatment
# 6. varaible imputation or transformers
# 7. variable creation
#
#
# - EDA Technique also called as feature engineering.

# %% [markdown]
# # Regression Algorithm (continuos data)
# 1. Simple linear Regression
# 2. Multiple linear Regression
# 3. Polynomial linear Regession
# 4. Lasso Regularization | L1 Regularization
# 5. Ridge Regularization | L2 Regularization
# 6. KNN Regression (k-nearest neighbour)
# 7. SVR Regression (Support vector regression)
# 8. DTR Regression (Decision Tree regression)
# 9. RFR Regression (Random Forest Regression)
# 10. XGB Regression (XG Boost)
# 11. LGBM Regression (Light Gradient Boosting Machine)
# 12. Time Series Regression

# %% [markdown]
# # Classification  Algorithm (catogorical data or binary data)
# 1. Logistic Regressin
# 2. SVM Model (Support Vector Machine)
# 3. DT (Decision Tree)
# 4. KNN Classifier
# 5. Random Forest
# 6. XG Boost
# 7. LGBM (Light Gradient Boosting Machine)
# 8. Naive Bais
# 9. ANN Classifier

# %% [markdown]
# # Clustering Algorithms (No dependent variable)
# 1. PCA (Principle Componet Analysis)
# 2. K-Means Cluster
# 3. Hiereachical Cluster
# 4. DBSCAN Cluster

# %% [markdown]
# # 16-Feb-2026

# %% [markdown]
# # EDA TEChnique
# 1. variable identification:
#      - independent variable
#      - depedendent variable
#      - relavant attribute :
#        **to identify relevant attribute  is very import because its lead the overfitting in the model**
#      - non -relavant attribute
# 2.  Univariate Analysis
#     - 1 variable analysis
# 3. Bivarate Analyis
#      - 2 variable analysi
#      - correlation
#        1. Positive corr (range(0 to 1)
#        2. negetive  (-1 to 0)
#        3. no corr (0)
#     - range the corr is -1 to 1
#
#      - every time we need to consider +ve corr
# 4. Outlier Treatment
#    - the value very far from the other observation
#
# 5. Missing Value Treatment
#     **how to fill missing values in data**
#    - if numerical data then fill with central tendency(mean,median)
#
#    - if categorical data is missing value fill with (mode)
#
#    - if mode is have mutliple  value then fill with  nearest neaghbour columns(knn)
#
#
# 6. Variable Imputation
#    -  imputation also called  (Transformer)
#    -  it will convert catogirical value into numerical value
#       **Technique**
#       - OHE (one hot encoding): it create columns for each unique value
#       - dummy model : binary value
#       - label encoder: convert data into numical data
#
# 7. Variable Creation
#    - from one feature we can build multiple variable

# %% [markdown]
# # EDA Practice

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df=pd.read_excel(r"E:\data\data_set\Rawdata.xlsx")

# %%
df
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
df.shape
# Out:
# (6, 6)

# %%
df.dtypes
# Out:
# Name        object
# Domain      object
# Age         object
# Location    object
# Salary      object
# Exp         object
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
df.isnull()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
df.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
df.describe()
# Out:
#         Name         Domain       Age Location  Salary Exp
# count      6              6         4        4       6   5
# unique     6              6         4        4       6   5
# top     Mike  Datascience#$  34 years   Mumbai  5^00#0  2+
# freq       1              1         1        1       1   1

# %% [markdown]
# # DATA CLEANING

# %%
df['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
df['Name']=df['Name'].str.replace(r'\W','',regex=True) # remove the  non char  string

# %%
df['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
index=False

# %%
df['Domain']=df['Domain'].str.replace(r'\W','',regex=True)

# %%
df['Domain']
# Out:
# 0    Datascience
# 1        Testing
# 2    Dataanalyst
# 3      Analytics
# 4     Statistics
# 5            NLP
# Name: Domain, dtype: object

# %%
df['Age']=df['Age'].str.replace(r'\W','',regex=True)

# %%
df['Age']
# Out:
# 0    34years
# 1       45yr
# 2        NaN
# 3        NaN
# 4       67yr
# 5       55yr
# Name: Age, dtype: object

# %%
df['Age']=df['Age'].str.extract('(\\d+)') #extract the digits

# %%
df
# Out:
#     Name       Domain  Age   Location   Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5^00#0       2+
# 1  Teddy      Testing   45  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst  NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics   67        NaN   30000-  5+ year
# 5    Kim          NLP   55      Delhi  6000^$0      10+

# %%
df['Salary']=df['Salary'].str.replace(r'\W','',regex=True)

# %%
df
# Out:
#     Name       Domain  Age   Location Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5000       2+
# 1  Teddy      Testing   45  Bangalore  10000       <3
# 2   Umar  Dataanalyst  NaN        NaN  15000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad  20000      NaN
# 4  Uttam   Statistics   67        NaN  30000  5+ year
# 5    Kim          NLP   55      Delhi  60000      10+

# %%
df['Exp']=df['Exp'].str.replace(r'\W','',regex=True)

# %%
df
# Out:
#     Name       Domain  Age   Location Salary    Exp
# 0   Mike  Datascience   34     Mumbai   5000      2
# 1  Teddy      Testing   45  Bangalore  10000      3
# 2   Umar  Dataanalyst  NaN        NaN  15000   4yrs
# 3   Jane    Analytics  NaN   Hyderbad  20000    NaN
# 4  Uttam   Statistics   67        NaN  30000  5year
# 5    Kim          NLP   55      Delhi  60000     10

# %%
df['Exp']=df['Exp'].str.extract('(\\d+)')

# %%
df
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
df.dtypes
# Out:
# Name        object
# Domain      object
# Age         object
# Location    object
# Salary      object
# Exp         object
# dtype: object

# %%
df1=df.copy()

# %%
df1
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %% [markdown]
# # EDA Techniques

# %% [markdown]
# ### Missing values imputation

# %%
df1.isna().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
df1['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
import numpy as np

# %%
df1['Age']=df1['Age'].fillna(np.mean(pd.to_numeric(df1['Age'])))

# %%
df1
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25        NaN  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  NaN
# 4  Uttam   Statistics     67        NaN  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
df1['Exp']=df1['Exp'].fillna(np.mean(pd.to_numeric(df1['Exp'])))

# %%
df1
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25        NaN  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  4.8
# 4  Uttam   Statistics     67        NaN  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
df['Location'].isnull().sum()
# Out:
# np.int64(2)

# %%
df['Location'].mode()
# Out:
# 0    Bangalore
# 1        Delhi
# 2     Hyderbad
# 3       Mumbai
# Name: Location, dtype: object

# %%
df1['Location']=df1['Location'].fillna(df1['Location'].mode()[0])

# %%
df1
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      object
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
df1['Salary']=df1['Salary'].astype(int)

# %%
df1['Age']=df1['Age'].astype(int)

# %%
df1['Exp']=df1['Exp'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      int64
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      int64
#  5   Exp       6 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 420.0+ bytes

# %%
df1.to_csv('clean_data.csv')
import os
os.getcwd()
# Out:
# 'C:\\Users\\USER\\DataScience_NareshIt\\Python_libraries\\Analysis_lib'

# %%
pwd
# Out:
# 'C:\\Users\\USER\\DataScience_NareshIt\\Python_libraries\\Analysis_lib'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Univariate Analysis

# %%
df1['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: int64

# %%
vis1=sns.distplot(df1['Salary'])
plt.show(vis1)

# %%
vis2=plt.hist(df1['Salary'])
plt.show(vis2)

# %% [markdown]
# # Bivariate Analysis

# %%
vis3=sns.lmplot(data=df1,x='Exp',y='Salary')
plt.show(vis3)

# %%
vis4=sns.lmplot(data=df1,x='Exp',y='Salary',fit_reg=False)
plt.show(vis4)

# %% [markdown]
# # Variable Imputaion

# %%
df1.columns

# %%
X=df1[['Name', 'Domain', 'Age', 'Location', 'Exp']]

# %%
y=df1['Salary']

# %%
df1

# %% [markdown]
# # Transformar

# %%
imputataion=pd.get_dummies(df1,dtype=int)

# %%
imputataion

# %%
imputataion.columns

# %%
imputataion.shape

# %%
# !pip install gradio

# %%
import gradio as gr

def greet(name):
    return "Hello " + name + "!"

demo = gr.Interface(fn=greet, inputs="text", outputs="text")
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Using existing dataset file at: .gradio\flagged\dataset1.csv
