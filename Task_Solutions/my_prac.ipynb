# %%
# largest number among three number
a= int(input('eneter a: '))
b= int(input('eneter b: '))
c= int(input('eneter c: '))

max_num=a
if max_num<b:
    max_num=b
if max_num<c:
    max_num=c
print(max_num)
# Out:
# eneter a:  45
# eneter b:  23
# eneter c:  56
# 56

# %%
# min
min_num=a
if min_num>b:
    min_num=b
elif min_num>c:
    min_num=c
print(min_num)
# Out:
# 23

# %%
n=[3,45,24999,4565,23,5]
max_n=n[0]
for i in n:
    if max_n<i:
        max_n=i
print(max_n)
# Out:
# 24999

# %%
n=[3,45,24999,4565,23,5]
min_n=n[0]
for i in n:
    if min_n>i:
        min_n=i
print(min_n)
# Out:
# 3

# %%
a=list(map(int,input('Enter numbers seperated by space: ').split()))
# Out:
# Enter numbers seperated by space:  34 234

# %%
min_a=a[0]
for i in a:
    if min_a>i:
        min_a=i
print(min_a)
# Out:
# 34

# %%
max_a=a[0]
for i in a:
    if max_a<i:
        max_a=i
    a=+1
print(max_a)
# Out:
# 234

# %%
n=list(map(int,input('Enter the int ').split()))
sum1=0
for i in n:
    sum1=sum1+i
print(sum1)
# Out:
# Enter the int  45 34 23
# 102

# %%
temp=float(input())
farenheit=(temp*1.8)+32
print(farenheit)
# Out:
#  45
# 113.0

# %%
yard=float(input())
meter=yard*0.9144
print(f'yard {yard}= {meter} m')
# Out:
#  456
# yard 456.0= 416.9664 m

# %%
lamb=float(input())
base=float(input())
karn=float(input())

if lamb+base+karn==180:
    print('Triangle is Possible')
  
else:
    print('not possible triangle')
# Out:
#  8
#  9
#  0
# not possible triangle

# %%
lamb=float(input())
base=float(input())
karn=float(input())
if  (lamb**2)+(base**2)==karn**2:
        print('satify pythogores')
else:
    print('tell me what is the theorem used in this')
# Out:
#  12
#  5
#  13
# satify pythogores
