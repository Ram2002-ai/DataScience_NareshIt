# %% [markdown]
# # Conditional Statements:
# - Conditional statements in Python are used to execute certain blocks of code based on specific conditions. These statements help control the flow of a program, making it behave differently in different situations.

# %% [markdown]
# # If conditional Statement
# - If statement is the simplest form of a conditional statement. It executes a block of code if the given condition is true.
# - ![image.png](attachment:c1e0e91d-7c13-497a-ada9-0e1c41a99394.png)!)

# %%
age = 20
if age >= 18:
    print("Eligible to vote.")
# Out:
# Eligible to vote.

# %% [markdown]
# # Short Hand if
# - Short-hand if statement allows us to write a single-line if statement.
#
# - This is a compact way to write an if statement. It executes print statement if the condition is true.

# %%
age = 19
if age > 18: print("Eligible to Vote.")
# Out:
# Eligible to Vote.

# %% [markdown]
# # If else Conditional Statement
# - If Else allows us to specify a block of code that will execute if the condition(s) associated with an if or elif statement evaluates to False. Else block provides a way to handle all other cases that don't meet the specified conditions.
# - ![image.png](attachment:3eafe9bf-b1b6-4d26-8a54-b8e596331871.png)!

# %%
age = 10
if age <= 12:
    print("Travel for free.")
else:
    print("Pay for ticket.")
# Out:
# Travel for free.

# %% [markdown]
# # Short Hand if-else
# - The short-hand if-else statement allows us to write a single-line if-else statement.
#
# - Note: This method is also known as ternary operator. Ternary Operator essentially a shorthand for the if-else statement that allows us to write more compact and readable code, especially for simple conditions.

# %%
marks = 45
res = "Pass" if marks >= 40 else "Fail"
print(f"Result: {res}")
# Out:
# Result: Pass

# %% [markdown]
# # elif Statement
# - elif statement in Python stands for "else if."
#
# - It allows us to check multiple conditions, providing a way to execute different blocks of code based on which condition is true.
#
# -  Using elif statements makes our code more readable and efficient by eliminating the need for multiple nested if statements.
#
# - ![image.png](attachment:9c8c78de-c55d-479c-9cd5-071c66d70e3d.png)!![image.png](attachment:d9f64445-2542-438b-b100-54ba8294ea73.png)!![image.png](attachment:f24332ca-f68b-4728-bd3a-21c721559fc4.png)!

# %%
age = 25

if age <= 12:
    print("Child.")
elif age <= 19:
    print("Teenager.")
elif age <= 35:
    print("Young adult.")
else:
    print("Adult.")
# Out:
# Young adult.

# %% [markdown]
# # Nested if..else Conditional Statement
# - Nested if..else means an if-else statement inside another if statement. We can use nested if statements to check conditions within conditions.
#
# - ![image.png](attachment:a33188eb-627c-4066-b1dd-01ebbbaf214a.png)!

# %%
age = 70
is_member = True

if age >= 60:
    if is_member:
        print("30% senior discount!")
    else:
        print("20% senior discount.")
else:
    print("Not eligible for a senior discount.")
# Out:
# 30% senior discount!

# %% [markdown]
# # Ternary Conditional Statement
# - A ternary conditional statement is a compact way to write an if-else condition in a single line. It’s sometimes called a "conditional expression."

# %%
# Assign a value based on a condition
age = 20
s = "Adult" if age >= 18 else "Minor"
print(s)
# Out:
# Adult

# %% [markdown]
# # Match-Case Statement
# - match-case statement is Python's version of a switch-case found in other languages. It allows us to match a variable's value against a set of patterns.

# %%
number = 2

match number:
    case 1:
        print("One")
    case 2 | 3:
        print("Two or Three")
    case _:
        print("Other number")
# Out:
# Two or Three

# %% [markdown]
# # Multiple Conditions in if Statement
# - Python provides two logical operators to combine conditions:
#
# - and: All conditions must be true. If the first condition is false, Python does not check the next one (short-circuiting).
#
#
# - or: At least one condition must be true. If the first condition is true, Python does not check the next one.

# %%
age = 18
if (age >= 8 and age <= 12):
    print("YOU ARE ALLOWED. WELCOME!")
else:
    print("SORRY! YOU ARE NOT ALLOWED. BYE!")
# Out:
# SORRY! YOU ARE NOT ALLOWED. BYE!

# %%
var = 'N'
if (var == 'Y' or var == 'y'):
    print("YOU SAID YES")
elif (var == 'N' or var == 'n'):
    print("YOU SAID NO")
else:
    print("INVALID INPUT")
# Out:
# YOU SAID NO

# %%
a = 7
b = 9
c = 3
if a > b and a > c:
    print(a, "is the largest")
elif b > a and b > c:
    print(b, "is the largest")
elif c > a and c > b:
    print(c, "is the largest")
else:
    print("All numbers are equal or there is a tie")
# Out:
# 9 is the largest

# %%
a = 1
b = 1
c = 1
if (a == 1 and b == 1 and c == 1):
    print("working")
else:
    print("stopped")
# Out:
# working

# %% [markdown]
# # Python if AND
# - In Python, if statement is a conditional statement that allows us to run certain code only if a specific condition is true.
# - By combining it with the AND operator, we can check if all conditions are true, giving us more control over the flow of our program.

# %%
a = 20  # age
b = True  # Citizen status
if a >= 18 and b:
    print("Eligible")
else:
    print("Ineligible")
# Out:
# Eligible

# %% [markdown]
# # Loops in Python - For, While and Nested Loops
# - Loops in Python are used to repeat actions efficiently. The main types are For loops (counting through items) and While loops (based on conditions).

# %% [markdown]
# # While Loop
# - In Python, a while loop is used to execute a block of statements repeatedly until a given condition is satisfied.
#
# - When the condition becomes false, the line immediately after the loop in the program is executed
#
#   ![image.png](attachment:1241febb-be11-451e-b1a9-c4b5f89d6816.png)!

# %%
cnt=0
while(cnt<3):
    cnt=cnt+1
    print('hello geek')
# Out:
# hello geek
# hello geek
# hello geek

# %% [markdown]
# # Infinite While Loop
# - If we want a block of code to execute infinite number of times then we can use the while loop in Python to do so.
#
# - Note: It is suggested not to use this type of loop as it is a never-ending infinite loop where the condition is always true and we have to forcefully terminate the compiler.

# %%
# while (True):
    # print("Hello Geek")

# %% [markdown]
# # For Loop
# - For loops is used to iterate over a sequence such as a list, tuple, string or range.
#
# - It allow to execute a block of code repeatedly, once for each item in the sequence
#
# - ![image.png](attachment:c52ea58e-7dd1-417b-beaf-3febef1122e9.png)

# %%
n = 4
for i in range(0, n):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
li = ["geeks", "for", "geeks"]
for x in li:
    print(x)
    
tup = ("geeks", "for", "geeks")
for x in tup:
    print(x)
    
s = "abc"
for x in s:
    print(x)
    
d = dict({'x':123, 'y':354})
for x in d:
    print("%s  %d" % (x, d[x]))
    
set1 = {10, 30, 20}
for x in set1:
    print(x),
# Out:
# geeks
# for
# geeks
# geeks
# for
# geeks
# a
# b
# c
# x  123
# y  354
# 10
# 20
# 30

# %% [markdown]
# # Iterating by Index of Sequences
# - We can also use the index of elements in the sequence to iterate.
# - The key idea is to first calculate the length of the list and then iterate over the sequence within the range of this length.

# %%
li = ["geeks", "for", "geeks"]
for index in range(len(li)):
    print(li[index],index)
# Out:
# geeks 0
# for 1
# geeks 2

# %% [markdown]
# # Nested Loops
# - Python programming language allows to use one loop inside another loop which is called nested loop.

# %%
# from __future__ import print_function
for i in range(1, 5):
    for j in range(i):
        print(i, end=' ')
    print()
# Out:
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %% [markdown]
# # Loop Control Statements
# - change execution from their normal sequence.
# -  When execution leaves a scope, all automatic objects that were created in that scope are destroyed.

# %% [markdown]
# # Continue Statement
# - The continue statement in Python returns the control to the beginning of the loop.
# - it skips the specific condition that is given inside the loop

# %%
for letter in 'geeksforgeeks':
    if letter == 'e' or letter == 's':
        continue
    print('Current Letter :', letter)
# Out:
# Current Letter : g
# Current Letter : k
# Current Letter : f
# Current Letter : o
# Current Letter : r
# Current Letter : g
# Current Letter : k

# %% [markdown]
# # Eval()

# %%
eval(input('2')) #change the string into float and int
# Out:
# 2 3

# %% [markdown]
# # Break Statement
# - The break statement in Python brings control out of the loop.

# %%
for letter in 'geeksforgeeks':
    if letter == 'e' or letter == 's':
        break

print('Current Letter :', letter)
# Out:
# Current Letter : e

# %%
for i in 'geeksforgeeks':
    if i == 'f' or i == 's':
        break
    print('Current Letter :', i)
# Out:
# Current Letter : g
# Current Letter : e
# Current Letter : e
# Current Letter : k

# %%
for i in range(11):
    if i==5:
        
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Pass Statement
# - We use pass statement in Python to write empty loops.
# -  Pass is also used for empty control statements, functions and classes.

# %%
for letter in 'geeksforgeeks':
    pass
print('Last Letter :', letter)
# Out:
# Last Letter : s

# %%
var = 10
for i in range(10):
    for j in range(2,10,1):
        if var % 2 == 0:
            continue #this conditon never false
        else:
            var += 1
print(var)
# Out:
# 10

# %% [markdown]
# # Using Else with Loops in Python
# - The else block just after for/while is executed only when the loop is NOT terminated by a break statement.

# %%
for i in range(1, 4):
    print(i)
else:  # Executed because no break in for
    print("No Break")
# Out:
# 1
# 2
# 3
# No Break

# %%
for i in range(1, 4):
    print(i)
    break
else: # Not executed as there is a break
    print("No Break")
# Out:
# 1

# %%
# Python 3.x program to check if an array consists 
# of even number
def contains_even_number(l):
    for ele in l:
        if ele % 2 == 0:
            print ("list contains an even number")
            break

    # This else executes only if break is NEVER
    # reached and loop terminated after all iterations.
    else:     
        print ("list does not contain an even number")

# Driver code
print ("For List 1:")
contains_even_number([1, 9, 8])
print (" \nFor List 2:")
contains_even_number([1, 3, 5])
# Out:
# For List 1:
# list contains an even number
#
# For List 2:
# list does not contain an even number

# %%
count = 0
while (count < 1):    
    count = count+1 # count=1
    print(count)
    break
else:
    print("No Break")
# Out:
# 1

# %% [markdown]
# # Printing Patterns in Python

# %%
print('# # # #')
print('# # # #')
print('# # # #')
print('# # # #')
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for i in range(1,5):
    i=i+1
    print('# # # #')
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for i in range(1,7):
    if i<=5:
        print('# # # #')
# Out:
# # # # #
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for j in range(4):
    print('#')
# Out:
# #
# #
# #
# #

# %%
for j in range(4):
    print('# # # #')
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for j in range(4):
    print('#',end=' ')
print()
for j in range(4):
    print('#',end=' ')
print()
for j in range(4):
    print('#',end=' ')
print()
for j in range(4):
    print('#',end=' ')
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for j in range(4):
    print('#',end=' ')
for j in range(4):
    print('#',end=' ')
# Out:
# # # # # # # # #

# %%
for j in range(4):
    print('#',end=' ')
print()

for j in range(4):
    print('#',end=' ')
print()

for j in range(4):
    print('#',end=' ')
print()

for j in range(4):
    print('#',end=' ')
print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for i in range(4):
    for j in range(4):
        print('#',end=' ')
    print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for i in range(4):
    for j in range(i+1):
        print('#',end=' ')
    print()
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(1,5):
    print('# '*i)
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(1,5):
    for j in range(4):
        if i>j:
            print('#',end=' ')
    print()
# Out:
# #
# # #
# # # #
# # # # #

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
for i in range(4):
    for j in range(i):
        print('#',end=' ')
    print()
# Out:
# #
# # #
# # # #

# %%
for i in range(4):
    for j in range(i+1):
        print('#',end=' ')
    print()
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(4):
    for j in range(4-i):
        print('$',end=' ')
    print()
# Out:
# $ $ $ $
# $ $ $
# $ $
# $

# %%
for i in range(5,0,-1):
    print('* '*i)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
# prime number - a number divisible by 1 or itself

# %%
n=14

for i in range(2,n):
    if n%i==0:
        print('Not prime number')
        break
else:
    print('Prime Number')
# Out:
# Not prime number

# %%
n=15

for i in range(2,n):
    if n%i==0:
        print('Not prime number')
        break
else:
    print('Prime Number')
# Out:
# Not prime number

# %% [markdown]
# # Given Tasks Questions solutions

# %% [markdown]
# # Input():
# - the input() in python is used for taking the input from the users.
# - its allways return string datatype if we want to int or float value we need to typecasting of input()

# %%
# to accept intergs from users
int(input())
# Out:
#  3
# 3

# %%
# to accept float from users
float(input())
# Out:
#  45.5
# 45.5

# %%
# multiple space -seperated values as input
input().split() #split() convert input into a list
# Out:
#  3 4,fs fds
# ['3', '4,fs', 'fds']

# %%
# number entered positive,negetive or zero
num=int(input())
if num>0:print('positive number')
elif num==0:print('zero number')
else:print('negetive number')
# Out:
#  44
# positive number

# %%
num=int(input())
if num>0:print('positive number')
elif num==0:print('zero number')
else:print('negetive number')
# Out:
#  0
# zero number

# %%
num=int(input())
if num>0:print('positive number')
elif num==0:print('zero number')
else:print('negetive number')
# Out:
#  -0939
# negetive number

# %%
# users input to list of integers
int((input()))
# Out:
#  90 3002 4040
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # users input to list of integers
# ----> 2 int((input()))
#
# ValueError: invalid literal for int() with base 10: '90 3002 4040'

# %%
# using list comprehension
nums=[int(x) for x in input('enter numbers:').split()]
# Out:
# enter numbers: 45 22 234 34

# %%
nums
# Out:
# [45, 22, 234, 34]

# %%
type(nums)
# Out:
# list

# %%
# space- separated intgers on one line
nums=list[map(int,input().split())]
# Out:
#  10 2837 23 34

# %%
# string input into uppercase
input().upper()
# Out:
#  sunil
# 'SUNIL'

# %%
# Write a Python program that accepts a string and prints the number of vowels in it. 
text = input("Enter a string: ") 
vowels = "aeiou" 
count = sum(1 for char in text if char.lower() in vowels) 
print("Number of vowels:", count)
# Out:
# Enter a string:  hunum
# Number of vowels: 2

# %%
# . Write a program that takes a number as input and checks if it is even or odd. 
n=int(input())
if n&1==0:
    print('even')
else:
    print('odd')
# Out:
#  45
# odd

# %%
# How would you check if a string is a palindrome using input()?
str=input()
if str==str[::-1]:
    print('palindrom')
else:
    print('Not a palindrom')
# Out:
#  kanak
# palindrom

# %%
# . Write a program that takes a number as input and prints its square. 
num=int(input())
print(num**2)
# Out:
#  6
# 36

# %%
# Write a program that asks for a number and prints whether it is divisible by 3. 
num=int(input())
if num%3==0:
    print('divisible')
else:
    print('not divisible')
# Out:
#  14
# not divisible

# %%
# How would you check if a number is divisible by both 3 and 7? 
num=int(input())
if num%3==0 and num%7==0:
    print('divisible by both')
else:
    print('not divisible by both')
# Out:
#  63
# divisible by both

# %%
# 14. How do you accept a list of comma-separated values as input?
input().split(',')
# Out:
#  hello,you,how,are,you
# ['hello', 'you', 'how', 'are', 'you']

# %%
# product of to input numbers
a,b=int(input()),int(input())
print(a*b)
# Out:
#  3
#  4
# 12

# %%
 # Write a program that checks if the input number is a prime number. 
def is_prime(n):
    if n <= 1:
        return False
    # Check divisors from 2 to sqrt(n)
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

num = int(input("Enter a number: "))

if is_prime(num):
    print(num, "is a prime number.")
else:
    print(num, "is not a prime number.")
# Out:
# Enter a number:  89
# 89 is a prime number.

# %%
for i in range(2,int(num**0.5)+1):
    if num%i==0:
        print('Not prime number')
        break
else:
    print('Prime Number')
# Out:
# Prime Number

# %%
# accept a boolean value from users
user_input=input('enter True or False ').lower()=='true'
# Out:
# enter True or False  false

# %%
# accept a reverse of user input
str=input()
print(str[::-1])
# Out:
#  revrese
# eserver

# %%
# *Question:** Write a program that asks for a user's name and age and prints a 
# message. 
name=input().title()
age=int(input())
print(f'Hello! {name} we happy to konow you {age} year old you are.')
# Out:
#  ronit
#  34
# Hello! Ronit we happy to konow you 34 year old you are.

# %%
# Write a program to calculate the factorial of a number using input(). 

num = int(input("Enter a number: ")) 
factorial = 1 
for i in range(1, num + 1): 
    factorial *= i 
    print("Factorial:", factorial)
# Out:
# Enter a number:  5
# Factorial: 1
# Factorial: 2
# Factorial: 6
# Factorial: 24
# Factorial: 120

# %%
# empty string determination
str=input().strip()
if not str:
    print('input string is empty')
else:
    print(str)
# Out:
# input string is empty

# %%
# Write a program to check if the entered number is a perfect square.
import math
num=int(input())
if math.isqrt(num)**2==num:
    print('perfect square')
else:
    print('not a perfect square')
# Out:
#  99
# not a perfect square

# %%
num=int(input())
if (int(num**0.5)*int(num**0.5))==num:
    print('perfect square')
else:
    print('not a perfect square')
# Out:
#  67
# not a perfect square

# %%
#  Write a program that asks the user for a year and determines if it's a leap year
year=int(input())
if (year%4==0 and year%100 !=0) or (year%400==0):
    print('Leap year')
else:
    print('Not a leap year')
# Out:
#  2023
# Not a leap year

# %%
# How can you remove leading and trailing spaces from a string input? 
str=input().strip()
print(str)
# Out:
#      ramesh
# ramesh

# %%
str=input().lstrip()
print(str,'  remove the leading spaces')
# Out:
#      ffdjh
# ffdjh remove the leading spaces

# %%
 # How do you handle incorrect inputs when you expect an integer using `input()`? 
 
try: 
       num = int(input("Enter a number: ")) 
except ValueError: 
       print("Invalid input! Please enter a valid integer.")
# Out:
# Enter a number:  8ds
# Invalid input! Please enter a valid integer.
