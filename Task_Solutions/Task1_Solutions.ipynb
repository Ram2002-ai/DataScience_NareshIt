# %%
age=25
print(age)
# Out:
# 25

# %%
number=20
print(number-1)
# Out:
# 19

# %%
# Sum of two numbers
a,b=23,20
sum=a+b
print(sum)
# Out:
# 43

# %%
# Area of a Rectangle
lenght=45
width=76
area=lenght*width
print(area)
# Out:
# 3420

# %%
# Area of a circle
radius=8.9
pi=3.14
area=radius**2*pi
print(area)
# Out:
# 248.71940000000004

# %%
# string concatanation
a='Learning'
b=' is fun!'
print(a+b)
# Out:
# Learning is fun!

# %% [markdown]
# # Arithmatic Operators in python

# %%
print((3+2)) #addition(+)
print(3-2) #subtraction(-)
print(3*2) #multiplication(*)
print(3/2) #division(/)
print(3**2) #exponential(**)
print(3%2) #modulus(%)
print(3//2) #Floor division operator(//)
# Out:
# 5
# 1
# 6
# 1.5
# 9
# 1
# 1

# %% [markdown]
# # Checking data types

# %%
print(type(10)) #int
print(type(2.12))#float
print(type(1+2j)) #complex
print(type(3e2)) #float
print(type('str')) #string
print(type([1,2,3])) #list
print(type({'r':202})) #dictionary
print(type((2,3,4))) #tuple
print(type({3.4,2.3,23})) #set
print(type(3==3)) #boolean
print(type(3 >=3)) #bolean
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'tuple'>
# <class 'set'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# # STRING : CHARACTER

# %%
# single line comment 
letter='p' # a string could be a single character or bunch of texts
print(letter) #print() :- display the values of the elements
print(len(letter)) #len() :- return the length of element
greeting ='Hello,World!' # a string coule have single or double quotes
print(greeting)
print(len(greeting))
sentence="I hope you are enjoying 30 days of python challange" #it is a single line string
print(sentence)
# Out:
# p
# 1
# Hello,World!
# 12
# I hope you are enjoying 30 days of python challange

# %% [markdown]
# # Multiline String

# %%
multiline_string='''I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of Python.'''
print(multiline_string)
# Out:
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of Python.

# %%
# Another way of doing same thing
multiline_string="""I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of Python."""
print(multiline_string)
# Out:
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of Python.

# %% [markdown]
# # String Concatenation

# %%
first_name="Ram"
last_name='Sevaiwar'
space=' '
full_name=first_name+space+last_name
print(full_name)

# Checking length of a string using len() builtin function
print(len(first_name))
print(len(last_name))
print(len(first_name) > len(last_name))
print(len(full_name))
# Out:
# Ram Sevaiwar
# 3
# 8
# False
# 12

# %% [markdown]
# # Unpacking characters

# %%
language='Python'
a,b,c,d,e,f=language # unpacking sequence of character into variables
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# P
# y
# t
# h
# o
# n

# %% [markdown]
# # Accessing characters in strings by index

# %%
print(language)
first_letter=language[0]
print(first_letter)
second_letter=language[1]
print(second_letter)
last_index=len(language)-1
last_letter=language[last_index]
print(last_index)
print(last_letter)
# Out:
# Python
# P
# y
# 5
# n

# %% [markdown]
# # Slicing

# %%
print(language)
first_three=language[0:3]
last_three=language[-3:]
print(first_three)
print(last_three)
All_letter=language[:] or language[::]
print(All_letter)
# Out:
# Python
# Pyt
# hon
# Python

# %% [markdown]
# # Steps Slicing
# Skipping characters while splitting Python string

# %%
print(language)
pto=language[0:6:2]
print(pto)
# Out:
# Python
# Pto

# %% [markdown]
# # Escape sequence

# %%
print('I hope everyone enjoying the python challenge. \nDo you?') #line break
print('Days\tTopics\tExercise')
print('Day 1\t3\t5') #creating a table structure
print('Day 2\t3\t5')
print('Day 3\t3\t5')
print('Day 4\t3\t5')
print('This is a back slash symbol(\\)') # To write back slash
print('In every programing it starts with \"Hello,World!\"')
# Out:
# I hope everyone enjoying the python challenge.
# Do you?
# Days	Topics	Exercise
# Day 1	3	5
# Day 2	3	5
# Day 3	3	5
# Day 4	3	5
# This is a back slash symbol(\)
# In every programing it starts with "Hello,World!"

# %% [markdown]
# # String Methods
# Capitalize():Converts the first character the string to Capital Letter

# %%
challenge='thirty days of python'
print(challenge.capitalize())
# Out:
# Thirty days of python

# %% [markdown]
# # Count():
# **returns occurrence of substring in string, count(substring, start=..,end=..)**

# %%
print(challenge)
print(challenge.count('y'))
print(challenge.count('y',7,14)) #start with 7 and ends with 13 index
print(challenge.count('th'))
# Out:
# thirty days of python
# 3
# 1
# 2

# %% [markdown]
# # Endwith()
# **Checks if a string ends with a specified characters**

# %%
print(challenge)
print(challenge.endswith('on')) 
print(challenge.endswith('tion'))
# Out:
# thirty days of python
# True
# False

# %% [markdown]
# # Expandtabs()
# **Replaces tab character with spaces, default tab size is 8. It takes tab size argument**

# %%
challange='thirty\tdays\tof\tpython'
print(challange.expandtabs())
print(challange.expandtabs(10)) #starts expanding after 10 index
# Out:
# thirty  days    of      python
# thirty    days      of        python

# %% [markdown]
# # Find()
# **returns the index of first occurrence of substring**

# %%
print(challenge)
print(challenge.find('y'))
print(challenge.find('th'))
# Out:
# thirty days of python
# 5
# 0

# %% [markdown]
# # format()
# **formats string into nicer output(nice way of presentation)**

# %%
print(first_name)
print(last_name)
job='student'
country='India'
sentence='I am {} {}.I am {}. I live in {}.'.format(first_name,last_name,job,country)
print(sentence)
# Out:
# Ram
# Sevaiwar
# I am Ram Sevaiwar.I am student. I live in India.

# %%
radius=10
pi=3.14
area=radius**2*pi
result='The area of circle with radius {} is {}.'.format(str(radius),str(area))
print(result)
# Out:
# The area of circle with radius 10 is 314.0.

# %% [markdown]
# # Index()
# **returns the first occurrence index of substring**

# %%
print(challenge)
print(challenge.index('y'))
print(challenge.index('th'))
print(challenge.index('ys'))
# Out:
# thirty days of python
# 5
# 0
# 9

# %% [markdown]
# # Isalnum()
# **Checks alphanumeric character**
# A string is alpha-numeric if all characters in the string are alpha-numeric and
# there is at least one character in the string

# %%
challenge='ThirtyDaysPython'
print(challenge.isalnum())
# Out:
# True

# %%
challenge='30DaysPython'
print(challenge.isalnum())
# Out:
# True

# %%
challenge='thirty days of python'
print(challenge.isalnum())
# Out:
# False

# %%
challenge='thirty days of python 2019'
challenge.isalnum(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 challenge='thirty days of python 2019'
# ----> 2 challenge.isalnum(1)
#
# TypeError: str.isalnum() takes no arguments (1 given)

# %%
challenge='thirty days of python 2019'
challenge.isalnum()
# Out:
# False

# %% [markdown]
# # Isalpha()
# **checks if all characters are alphabets**

# %%
challenge='thirtydaysofpython'
print(challenge.isalpha())
challenge='thirty days of python'
print(challenge.isalpha())
num='123'
print(num.isalpha())
# Out:
# True
# False
# False

# %% [markdown]
# # IsDecimal()
# **checks decimals characters**

# %%
print(challenge)
print(challenge.isdecimal())
deci='1,2,3,4.3'
d='10.20,2.1,3.2'
e='1'
print(e.isdecimal())
print(deci.isdecimal())
print(d.isdecimal())
print(e.isdecimal())
# Out:
# thirty days of python
# False
# True
# False
# False
# True

# %% [markdown]
# # Isdigit()
# **checks digit characters**

# %%
challenge='Therty'
print(challenge.isdigit())
num='0'
print(num.isdigit())
# Out:
# False
# True

# %% [markdown]
# # IsIdentifier()
# ** Checks for valid identifier means it check if a string valid variable name**

# %%
challenge='20daysofpython'
print(challenge.isidentifier()) #because it starts with 20
challenge='thirty_days_of_python'
print(challenge.isidentifier())
# Out:
# False
# True

# %% [markdown]
# # IsLover()
# **Checks if all alphabets in a string are lowercase**

# %%
challenge='thirty days of python'
print(challenge.islower())
challenge='Thirty days of python'
print(challenge.islower())
# Out:
# True
# False

# %% [markdown]
# # IsUpper()
# **Returns if all characters are uppercase characters**

# %%
challenge='thirty days of python'
print(challenge.isupper())
challenge='THIRTY DAYS OF PYTHON'
print(challenge.isupper())
# Out:
# False
# True

# %% [markdown]
# # IsNumeric()
# ** checks numeric characters**

# %%
num='102'
print(num.isnumeric())
print('ten'.isnumeric())
# Out:
# True
# False

# %% [markdown]
# # Join()
# **Returns a concatenated string**

# %%
web_tech=['HTML','CSS','JavaScript','React']
result=' language, '.join(web_tech) #join the list #
l=' '.join(web_tech)
print(result)
print(l)
# Out:
# HTML language, CSS language, JavaScript language, React
# HTML CSS JavaScript React

# %% [markdown]
# # strip()
# **Return a copy of the string with trailing whitespace removed**

# %%
challenge='    thirty    days of python' #i have problem
print(challenge.strip('y'))
print(challenge.rstrip('y'))
print(challenge.lstrip('y'))
# Out:
#     thirty    days of python
#     thirty    days of python
#     thirty    days of python

# %% [markdown]
# # Lstrip()
# Return a copy of the string with leading whitespace removed.

# %%
print(challenge)
print(challenge.lstrip())
print(challenge)
# Out:
#     thirty    days of python
# thirty    days of python
#     thirty    days of python

# %% [markdown]
# # Replace()
# **Replaces substring inside**

# %%
challenges='thirty days of python'
print(challenges.replace('python','coding'))
print(challenges)
# Out:
# thirty days of coding
# thirty days of python

# %% [markdown]
# # Split()
# **Splits string from left**

# %%
challenge='thirty days of python'
print(challenges.split()) #split text into list
# Out:
# ['thirty', 'days', 'of', 'python']

# %% [markdown]
# # Title()
# **Returns a Title Cased Sting**

# %%
challenge='thirty days of python'
print(challenge.title()) #capatalize the text all starting character
# Out:
# Thirty Days Of Python

# %% [markdown]
# # Swapcase()
# **Change the string charaters case of text**

# %%
challenges='thirty days of python'
print(challenges.swapcase()) #change the case of text
challenge='Thirty days of Python'
print(challenge.swapcase())
# Out:
# THIRTY DAYS OF PYTHON
# tHIRTY DAYS OF pYTHON

# %% [markdown]
# # Startwith
# **Checks if String Start with the Specified String**

# %%
challenges='thirty days of python'
print(challenges.startswith('thirty'))
challenge='30 days of python'
print(challenges.startswith)
# Out:
# True

# %% [markdown]
# # Python Variables

# %%
first_name="Ram"
last_name='Sevaiwar'
country="India"
city='Balaghat'
age=23
is_married=False
skills=['Python','MS Excel','PowerBI','ML','DS']
personal_info={
    'First_name':'JOhn',
    'last_name': 'styline',
    'country':'italy',
    'city':'milan'
}

# %% [markdown]
# # Printing the values stored in the variables

# %%
print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', personal_info)
# Out:
# First name: Ram
# First name length: 3
# Last name:  Sevaiwar
# Last name length:  8
# Country:  India
# City:  Balaghat
# Age:  23
# Married:  False
# Skills:  ['Python', 'MS Excel', 'PowerBI', 'ML', 'DS']
# Person information:  {'First_name': 'JOhn', 'last_name': 'styline', 'country': 'italy', 'city': 'milan'}

# %% [markdown]
# # Declaring multiple variables in one line

# %%
first_name, last_name, country, age, is_married = 'prakash', 'senapati', 'Helsink', 250, True

print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# prakash senapati Helsink 250 True
# First name: prakash
# Last name:  senapati
# Country:  Helsink
# Age:  250
# Married:  True

# %% [markdown]
# # PYTHON OPERATORS
# **Python operators are special symbols used to perform operations on variables and values. They are grouped into categories such as arithmetic, assignment, comparison, logical, identity, membership, and bitwise operators.**

# %% [markdown]
# # 1.ARITHMETIC OPERATORS
# - (+) → Addition (5 + 2 = 7)
# - (-) → Subtraction (4 - 2 = 2)
# - (*) → Multiplication (2 * 3 = 6)
# - / → Division (4 / 2 = 2.0)
# - // → Floor Division (10 // 3 = 3)
# - % → Modulus (5 % 2 = 1)
# - ** → Exponentiation (4 ** 2 = 16)

# %%
x,y=10,5
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x**y)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %% [markdown]
# # 2. Assignment Operators
# Used to assign values to variables:
# - = → Simple assignment (x = 5)
# - += → Add and assign (x += 3)
# - -= → Subtract and assign (x -= 2)
# - *= → Multiply and assign (x *= 4)
# - /= → Divide and assign (x /= 2)
# - %= → Modulus and assign (x %= 3)
# - **= → Exponentiation and assign (x **= 2)
# - //= → Floor division and assign (x //= 2)

# %%
x += 2
x
# Out:
# 14

# %%
x -= 2
x
# Out:
# 12

# %%
print(x)
print(x += 2)
print(x -= 2)
print(x *= 2)
print(x /= 2)
print(x %= 2)
print(x **= 2)
print(x //= 2)
# Out:
#   Cell In[12], line 2
#     print(x += 2)
#             ^
# SyntaxError: invalid syntax

# %%
x %= 2
x
# Out:
# 0

# %%
x=90
x **= 2
x
# Out:
# 8100

# %%
x //= 2
x
# Out:
# 4050

# %%
x *= 2
x
# Out:
# 16200

# %%
x /= 2
x
# Out:
# 8100.0

# %% [markdown]
# # 3. UNARY OPERATOR

# %%
N=7 #negation
N
# Out:
# 7

# %%
m=-N
m
# Out:
# -7

# %% [markdown]
# # 4. Comparison Operators(Relational Operator)
# Used to compare values:
# - == → Equal to
# - != → Not equal to
# - (>) → Greater than
# - (<) → Less than
# - (>=) → Greater than or equal to
# - <= → Less than or equal to

# %%
a,b=5,6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a !=b
# Out:
# True

# %%
a <=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a=b

# %%
a ==b
# Out:
# True

# %% [markdown]
# # 5. Logical Operators
# Used to combine conditional statements:
# - and → Returns True if both conditions are true
# - or → Returns True if at least one condition is true
# - not → Reverses the result (not True = False)
#
# . No symbol equivalents:
# - You cannot use &&, ||, or ! in Python.
# - If you try, Python will throw a SyntaxError.

# %%
a,b=5,4

# %%
 a<8 and b<5
# Out:
# True

# %%
a<b or b>5
# Out:
# False

# %%
a<8 or a>6
# Out:
# True

# %%
y1= not False
y1
# Out:
# True

# %%
x1= not y1
x1
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# # 6. Identity Operators
# Used to compare memory locations:
# - is → Returns True if both variables point to the same object
# - is not → Returns True if they do not
#
# # 7. Membership Operators
# Used to check for membership in sequences:
# - in → Returns True if a value is found in a sequence
# - not in → Returns True if a value is not found
#
# # 8. Bitwise Operators
# Used to perform operations on binary numbers:
# - & → AND
# - | → OR
# - ^ → XOR
# - ~ → NOT (inverts bits)
# - << → Left shift
# - (>>) → Right shift
