# %% [markdown]
# # Linear Regression
# - y=mx+c
#      - how machine will build future
#
#      - x=1,2,3,4,5 , xmean=3
#
#      - y=3,4,2,4,5 , ymean=3.6
#
# - we have the x and y
#   #### les compute m,c
#
#   - m= sum(x-xbar)(y-ybar)/sum(x-xbar)**2
#
#   - c=y-mx
#
#   - y=0.4*1+2.4=2.8
#
#
#     y=0.4*2+2.4=3.2
#
#     y=0.4*3+2.4=3.6
#
#     y=0.4*4+2.4=4
#
#     y=0.4*5+2.4=4.4
#
#
# - if connect all the predicted points we get a best fit line in the graph

# %% [markdown]
# ### training data==(X_train,y_train)== bias
# ### testing data ==(X_test,y_test)==variance
#
#   1. bias- 43 variance -80 (overfitting)
#   2. bias- 80 variance - 43 (underfiting)
#   3. bias-90 variance -89 (best fit model) (low bias | low variance)
#
# bias - training
# variance - testing

# %% [markdown]
# ##

# %% [markdown]
# # Multiple Linear Regression
#
# - Feature Selection or feature selection
# - back ward feature selection
# - how did you select feature based on rfe (recurssive feature selection)
#
# - Feature Engineering- EDA
# - feature Scaling- standardarization & normalizaton
# - feature Selection- rfe ,backward elimination

# %% [markdown]
# # Regularization Technique
# - when the model overfits then we apply regularization
#   - pca|cross validation|ensamble learning|drop out the neurouns
# ##### Types of Regularization
#  1. ridge |regularization|l2- we regularize high coef to low coef to reduce overfiting
#  2. lasso|regularization|l1- we regularize high coef to 0 so that we can reduce overfiting
#  3. elasticnet|l1+l2
#
# - lasso also called as feature selection technique or feature elimination technique

# %% [markdown]
# - it regularize high coeff to low coeff -l2
# - it regularize high coef to 0 -l1

# %% [markdown]
# # Polynomial Regression
#  poly nomial y=b0+b1x1+b2x2**2+.............

# %% [markdown]
# # Support Vector Regression(svr)
# - best fit line called hyperplan
# - formula
#     y=wx+b
# - decision boundary=support vector
# - the distance b/w  two support vector is called marginal distance
#
#      -a<y=wx+b<+a
# - the distance b/w two support vector is maximum
#
# - support vector is the nearest distance from the hyperplane upward and downward

# %%
# after the model training we have to build the model ranking table

# %% [markdown]
# # KNN model(k-nearest neighbour)
# - distance matrix will be used in knn
#     1. euclidian distance (distance b/w 2 points)- shortest distance
#     2. manhateen distance(distance b/w 2 points)-(farthest distance)
#     3. cosine distance-(distance b/w 2 text)

# %% [markdown]
# # CART(Classification+Regression)
# ### Tree Algorithm
#     1. decision tree
#     2. random forest
#     3. feature scaling
#     4. project using flask
#         house price prediction we apply 14 algorithm at once go
#     5. resume project
#         sales forecating
#
# - regression--decission tree regression
# - classification decission tree classifier
# - Tree always classify the data
#
#
# - how to build tree from the dataset
#
#
# ### Random forest
# - decission tree-tree will make you decission
#
# - Randomly make trees and take decision on majority
#
#   ##### ensamble learning
#
#   - bagging
#         - random forest
#   - boosting
#         - xgboost
#         - gradient boost
#
# ### Feature Scalling
#
# - feature selection
#   - bussiness underting
#   - rfe(recursive feature selection)
#   - based on p-value (wraper method)
#
# - feature Engineer
#
#   - Eda technique
#   - variable indentification,univariate
# - feature scalling
#
#   - standardization
#   - normalization(min-max scaller)
#     - values 0-1

# %%
# Flask 
- flask is a web framework to build the frontend

# %% [markdown]
# # House Price Prediction Regression Project
# - Resume Projects

# %% [markdown]
# # workflow
# - bussiness understanding
#       - attribute understanding
#           -data cleaning
#               - identify the the dependent and indipendent feature
#                   -eda-outlier detection
#                       -spliting data-feature scalling
#                               -feature encoding
#                                   - model building
#                                       - feature selection
#                                           - accuracy scores
#                                               - pickle the model
#                                                   - frontend
#                                                       - deployemnet

# %% [markdown]
# # Classification
# - dependent variable is binary or category
# - performace measures of regression -R2 and adjusted r2
#     range 0-1
#
# - performance measure of classification -confusion matrix
#
# ### Classification algo
#     - Logistic regression
#     - svm
#     - naive bais
#     - dt
#     - rf
#     - Xgboost
#     - lgbm
#     - ann classification

# %% [markdown]
# # Overfiting
# - train the model will more attribute
# - if model overfits high error and low accuracy
#
# technique to reduce overfitting
#     - pca
#     - regularization
#     - ensamble learning
#     - drop out neuron
#     - cross validation
# ## Underfitting
# - train the model with less attribute
#
# - identify right attribute is important -- model never overfits good accuracy

# %% [markdown]
# # Confusion Matrix
# - true +ve (yes&yes)
# - true -ve (yes & no)
# - false +ve (no & yes)
# - false -ve (no & no )
#
# ### model accuracy
# - accuracy=(tp+tn)/total
#
# - error=1 -accuracy
# - formula = (fp+fn)/total
#
#
# ### Precision
# - precision=tp/predicted yes
# - recal=tp/actual yes
#
#
# # F1 -score
# - f1 score= (2*precision*recal)/(precision+recal)
#
# ### Gragh of Confusion matrix
# - AUC (area under curve) (x axis=fpr) (y axis=tpr)
# - ROC (receiver operating characterstic)
#
# - Fpr=sensitivity
# - tpr=specifity
#  tpr=tp/(tp+fn)
#  fpr=tn/(tn+fp)

# %% [markdown]
# # Logistic Regression
# - logistic regression is classification algorithm
# - then why mension as regression
#
# - 2-algo logistic regression and naiye bais
#
# - the regression line classify
# - sigmoid function
#   - sigmoid function range(0-1)
#   - in deep learning this concept we called as sigmoid activation function
#
#     sigmoid func(p)=1/(1-e**-1)
#
# - logistic regression we get best fit curve
# -

# %% [markdown]
# - overfiting technique
#
#     cross vali
#
#     gridsearch cv
#
#     random search cv

# %% [markdown]
# # Validation
# - we have historical data we have dependent var
# - for future data we don't have dependent var
# - we are build ml to predict future after prediction we compare with live data

# %% [markdown]
# # SVM
# - ![image.png](attachment:de9b541d-64d9-4e27-808d-ca7b6c25e670.png)
#
# - distance b/w two support vector called marginal distance
#
# - maximum marginal distance
#
#
# ### non-linear svm
#  - we can not divede two classees
#  - need to apply kernel
#
# ![image.png](attachment:2a9e6723-ccd3-4502-8851-1a8ff4e583e7.png)

# %% [markdown]
# # Gemini-Api key
# AIzaSyBZSGnd_k_U418ESdMENU9cfPPIT-AVpWQ
