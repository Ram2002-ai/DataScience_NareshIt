# %% [markdown]
# # Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("E:\data\data_set\Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %% [markdown]
# # Spliting Data

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X,y
# Out:
# (    YearsExperience
#  0               1.1
#  1               1.3
#  2               1.5
#  3               2.0
#  4               2.2
#  5               2.9
#  6               3.0
#  7               3.2
#  8               3.2
#  9               3.7
#  10              3.9
#  11              4.0
#  12              4.0
#  13              4.1
#  14              4.5
#  15              4.9
#  16              5.1
#  17              5.3
#  18              5.9
#  19              6.0
#  20              6.8
#  21              7.1
#  22              7.9
#  23              8.2
#  24              8.7
#  25              9.0
#  26              9.5
#  27              9.6
#  28             10.3
#  29             10.5,
#  0      39343
#  1      46205
#  2      37731
#  3      43525
#  4      39891
#  5      56642
#  6      60150
#  7      54445
#  8      64445
#  9      57189
#  10     63218
#  11     55794
#  12     56957
#  13     57081
#  14     61111
#  15     67938
#  16     66029
# ...

# %% [markdown]
# # Holdout Validation Method
#
# - It is a type of model validation technique used in Machine Learning.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # LinearRegression
#
# - LinearRegression is a Supervised Machine Learning algorithm used for:
#
# - 🎯 Predicting continuous numerical values
#
# - It belongs to:
#
#     📚 Regression Algorithms
#     📊 Statistical Modeling
#
# - its work only for
#
# # Mathematical Concept
#     y=mx+c
# - y = of target variable
# - x = mean of indipendent variable
# - c= intercept
# - m= slope (coefficient)
#
# ### formula for calculating the m
#      - m= sum((x-xbar)(y-ybar))/sum(x-xbar)**2
#      - c=y-mx

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### predict() is a method used to generate output predictions from a trained machine learning model.
#
# - What Happens Internally?
#
# After training, the model stores:
#
# regressor.coef_ → slope (m)
#
# regressor.intercept_ → intercept (c)

# %%
y_pred=regressor.predict(X_test)

# %%
comparision=pd.DataFrame({'Actual':y_test,'Prediction':y_pred})
comparision
# Out:
#     Actual     Prediction
# 27  112635  115573.622884
# 15   67938   71679.938782
# 23  113812  102498.908470
# 17   83088   75415.571471
# 8    64445   55803.499851
# 9    57189   60473.040713
# 28  122391  122110.980090
# 24  109431  107168.449332
# 12   56957   63274.765230

# %%
plt.scatter(X_test,y_test,color='Red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Salary of employee based on experiance')
plt.xlabel('Experience')
plt.ylabel('salary')
plt.grid(True)
plt.show()

# %% [markdown]
# #### slope (coeficeint)
# - How much the target (y) changes when one feature (x) increases by 1 unit.

# %%
# predict future
m_coef=regressor.coef_  # slope of the line (angle) of best fit line
m_coef
# Out:
# array([9339.08172382])

# %% [markdown]
# #### Intercept (intercept_)
# 👉 Meaning:
#
# - The starting value of y when x = 0
#
# - It is the point where the regression line crosses the Y-axis.

# %%
c_intercept=regressor.intercept_
c_intercept
# Out:
# np.float64(25918.438334893217)

# %%
20*m_coef+c_intercept
# Out:
# array([212700.0728112])

# %%
bias=regressor.score(X_train,y_train)
print(bias)
# Out:
# 0.9574526669392872

# %%
variance=regressor.score(X_test,y_test)
variance
# Out:
# 0.9414466227178214

# %%
m_coef*6+c_intercept
# Out:
# array([81952.92867778])

# %%
# creating a dataset of cgpa vs pacakage

# %%
np.random.seed(0)
package=pd.DataFrame({
    'cgpa': np.round(np.random.uniform(5, 10, 200), 2),
    'package in lpa':np.random.randint(2,15,200)
})
package
# Out:
#      cgpa  package in lpa
# 0    7.74               8
# 1    8.58               9
# 2    8.01               4
# 3    7.72              14
# 4    7.12              13
# ..    ...             ...
# 195  7.45               3
# 196  6.14               2
# 197  6.27               9
# 198  5.29              10
# 199  7.17              12
#
# [200 rows x 2 columns]

# %%
X=package.iloc[:,:-1]
y=package.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
comparision = pd.DataFrame({'Actual': y_test, 'Prediction': y_pred})
print(comparision)
# Out:
#      Actual  Prediction
# 95       13    7.807656
# 15       14    7.830002
# 30       10    7.789033
# 158      10    7.755514
# 128       4    7.696854
# ..      ...         ...
# 97       12    7.845831
# 31       13    7.670318
# 12        2    7.718270
# 35        5    7.706631
# 119       8    7.689405
#
# [66 rows x 2 columns]

# %%
plt.scatter(X_test, y_test, color = 'Red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary of employee based on experience')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
m_coef = regressor.coef_
print(m_coef)

c_intercept = regressor.intercept_
print(c_intercept)

y_20 = m_coef * 20 + c_intercept
print(y_20)


bias = regressor.score(X_train, y_train)
print(bias)

variance = regressor.score(X_test, y_test)
print(variance)
# Out:
# [-0.04655518]
# 8.083262235484673
# [7.15215861]
# 0.00029844360150788063
# -0.060988196811909035

# %%
m_coef
