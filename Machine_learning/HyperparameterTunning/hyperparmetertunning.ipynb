# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(max_iter=200)

# %%
rfe=RFE(
    model,
    n_features_to_select=2
)

# %%
rfe.fit(X,y)
# Out:
# RFE(estimator=LogisticRegression(max_iter=200), n_features_to_select=2)

# %%
rfe.support_
# Out:
# array([False, False,  True,  True])

# %%
rfe.ranking_
# Out:
# array([3, 2, 1, 1])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
X=df[['petal_length','petal_width']]

# %%
y=df['species']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
ss=StandardScaler()

# %%
le=LabelEncoder()

# %%
x_train_scaled=ss.fit_transform(X_train)

# %%
x_scalled_test=ss.fit_transform(X_test)

# %%
y_label=le.fit_transform(y_train)

# %%
y_label_test=le.fit_transform(y_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
knn=KNeighborsClassifier()

# %%
param_grid={
    'n_neighbors':[3,5,7,9,11,13,15],
    'weights': {'uniform', 'distance'},
    'algorithm' : {'auto', 'ball_tree', 'kd_tree', 'brute'},
    'metrics':{'ecludian','manhattam'}}

# %%
grid=GridSearchCV(
    estimator=model1,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy'
)

# %%
param_grid = {
    'n_neighbors': [3,5,7,9],
    'weights': ['uniform','distance']   # ✅ list
}

from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(estimator=knn,
                    param_grid=param_grid,
                    cv=5,
                    scoring='accuracy')

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
grid.set_params
# Out:
# <bound method BaseEstimator.set_params of GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')>

# %%
grid.error_score
# Out:
# nan

# %%
grid.score
# Out:
# <bound method BaseSearchCV.score of GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')>

# %%
grid.best_params_
# Out:
# {'n_neighbors': 5, 'weights': 'uniform'}

# %%
model1=KNeighborsClassifier(
    {'n_neighbors': 5, 'weights': 'uniform','algorithm':ball_tree }
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[148], line 2
#       1 model1=KNeighborsClassifier(
# ----> 2     {'n_neighbors': 5, 'weights': 'uniform','algorithm':ball_tree }
#       3 )
#
# NameError: name 'ball_tree' is not defined

# %%
model1.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 model1.fit(X_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1329, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1324 partial_fit_and_fitted = (
#    1325     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1326 )
#    1328 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
#    1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:492, in BaseEstimator._validate_params(self)
#     484 def _validate_params(self):
#     485     """Validate types and values of constructor parameters
#     486
#     487     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    490     accepted constraints.
#     491     """
# --> 492     validate_parameter_constraints(
#     493         self._parameter_constraints,
#     494         self.get_params(deep=False),
#     495         caller_name=self.__class__.__name__,
#     496     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'n_neighbors' parameter of KNeighborsClassifier must be an int in the range [1, inf) or None. Got {'n_neighbors': 5, 'weights': 'uniform'} instead.
