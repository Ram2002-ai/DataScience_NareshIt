# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "adult.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "shreyshi/adultcsv",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13156\2284079936.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\kagglehub\pandas_datasets.py:92, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      91 try:
# ---> 92     result = read_function(
#      93         *_build_args(read_function, filepath, sql_query),
#      94         **_build_kwargs(file_extension, pandas_kwargs),
#      95     )
#      96 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:325, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x9d in position 11: invalid start byte
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 10
#       7 file_path = r"adult.csv"
#       9 # Load the latest version
# ---> 10 df = kagglehub.load_dataset(
#      11   KaggleDatasetAdapter.PANDAS,
#      12   "shreyshi/adultcsv",
#      13   file_path,
#      14   # Provide any additional arguments like
#      15   # sql_query or pandas_kwargs. See the
#      16   # documenation for more information:
#      17   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
#      18 )
#      20 df
#
# File ~\anaconda3\Lib\site-packages\kagglehub\datasets.py:192, in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     177 def load_dataset(
#     178     adapter: KaggleDatasetAdapter,
#     179     # In the form of {owner_slug}/{dataset_slug} or {owner_slug}/{dataset_slug}/versions/{version_number}
#    (...)    185     hf_kwargs: Any = None,  # noqa: ANN401
#     186 ) -> Any:  # noqa: ANN401
#     187     warnings.warn(
#     188         "Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.",
#     189         DeprecationWarning,
#     190         stacklevel=2,
#     191     )
# --> 192     return dataset_load(adapter, handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query, hf_kwargs=hf_kwargs)
#
# File ~\anaconda3\Lib\site-packages\kagglehub\datasets.py:155, in dataset_load(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs, polars_frame_type, polars_kwargs)
#     152 elif adapter is KaggleDatasetAdapter.PANDAS:
#     153     import kagglehub.pandas_datasets  # noqa: PLC0415
# --> 155     return kagglehub.pandas_datasets.load_pandas_dataset(
#     156         handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query
#     157     )
#     158 elif adapter is KaggleDatasetAdapter.POLARS:
#     159     import kagglehub.polars_datasets  # noqa: PLC0415
#
# File ~\anaconda3\Lib\site-packages\kagglehub\pandas_datasets.py:98, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      96 except Exception as e:
#      97     read_error_message = f"Error reading file: {e}"
# ---> 98     raise ValueError(read_error_message) from e
#     100 return result
#
# ValueError: Error reading file: 'utf-8' codec can't decode byte 0x9d in position 11: invalid start byte
